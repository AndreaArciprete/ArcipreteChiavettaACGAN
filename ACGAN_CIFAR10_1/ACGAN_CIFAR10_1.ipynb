# %%
#Import librerie di cui necessitiamo
import argparse
import os
import numpy as np
import math

import torchvision.transforms as transforms
from torchvision.utils import save_image

from torch.utils.data import DataLoader
from torchvision import datasets
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F
import torch

# %%
"""Creiamo una directory in cui andremo a salvare tutte le immagini che man mano
verranno generate in fase di training del modello per valutare quanto il modello
sta funzionando bene"""
os.makedirs("results_images", exist_ok=True)

# %%
"""Sfruttando la libreria argparse creiamo una sorta di namespace contenente
tutte le variabili che ci serviranno da ora in avanti"""
parser = argparse.ArgumentParser()
parser.add_argument('-f')
parser.add_argument("--n_epochs", type=int, default=600, help="number of epochs of training")
parser.add_argument("--batch_size", type=int, default=64, help="size of the batches")
parser.add_argument("--lr", type=float, default=0.0002, help="adam: learning rate")
parser.add_argument("--b1", type=float, default=0.5, help="adam: decay of first order momentum of gradient")
parser.add_argument("--b2", type=float, default=0.999, help="adam: decay of first order momentum of gradient")
parser.add_argument("--n_cpu", type=int, default=4, help="number of cpu threads to use during batch generation")
parser.add_argument("--latent_dim", type=int, default=100, help="dimensionality of the latent space")
parser.add_argument("--n_classes", type=int, default=10, help="number of classes for dataset")
parser.add_argument("--img_size", type=int, default=32, help="size of each image dimension")
parser.add_argument("--channels", type=int, default=3, help="number of image channels")
parser.add_argument("--sample_interval", type=int, default=10, help="interval between image sampling")
opt = parser.parse_args()
print(opt)
# Out:
# Namespace(b1=0.5, b2=0.999, batch_size=64, channels=3, f='/root/.local/share/jupyter/runtime/kernel-15bebdef-58a4-4f1c-a236-df7ae226268e.json', img_size=32, latent_dim=100, lr=0.0002, n_classes=10, n_cpu=4, n_epochs=600, sample_interval=10)

# %%
"""Al reference cuda assegniamo True se la GPU è disponibile, altrimenti gli
assegniamo False"""
cuda = True if torch.cuda.is_available() else False

# %%
"""Tale funzione come parametro riceve un modulo presente all'interno del
generatore o del discriminatore e se il modulo è di tipo Conv o sottotipo di
Conv (ad esempio Conv2d) allora vengono inizializzati i pesi di tale modulo, se
il modulo è di tipo BatchNorm2d allora vengono inizializzati i pesi e i bias di
tale modulo"""
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("BatchNorm2d") != -1:
        torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant_(m.bias.data, 0.0)

# %%
"""Modello del generatore"""
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.label_emb = nn.Embedding(opt.n_classes, opt.latent_dim)

        self.fcl = nn.Linear(opt.latent_dim, 128 * (opt.img_size // 4) * (opt.img_size // 4))

        self.conv_layers = nn.Sequential(
            nn.BatchNorm2d(128),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),

            nn.BatchNorm2d(128, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),

            nn.BatchNorm2d(64, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, opt.channels, kernel_size=3, padding=1),

            nn.Tanh()
        )

    def forward(self, noise, labels):
        gen_input = torch.mul(self.label_emb(labels), noise)
        fcl_out = self.fcl(gen_input)
        img = fcl_out.view(fcl_out.size(0), 128, opt.img_size // 4, opt.img_size // 4)
        imgs = self.conv_layers(img)
        return imgs

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        def block(in_channels, out_channels, bn=True):
            layers = nn.ModuleList([nn.Conv2d(in_channels, out_channels, 3, 2, 1),
                                    nn.LeakyReLU(0.2, inplace=True),
                                    nn.Dropout2d(0.2)])
            if bn:
                layers.append(nn.BatchNorm2d(out_channels, 0.8))
            return layers

        self.conv_layers = nn.Sequential(
            *block(opt.channels, 16, bn=False),
            *block(16, 32),
            *block(32, 64),
            *block(64, 128)
        )

        self.adv_layer = nn.Sequential(
            nn.Linear(128 * 2 * 2, 1),
            nn.Sigmoid()
        )


        self.aux_layer = nn.Sequential(
            nn.Linear(128 * 2 * 2, opt.n_classes),
            nn.Softmax()
        )


    def forward(self, img):
        img = self.conv_layers(img)
        fcl_in = img.view(img.size(0), -1)
        validity = self.adv_layer(fcl_in)
        label = self.aux_layer(fcl_in)
        return validity, label

# %%
#Definiamo le Loss Function che ci serviranno"""
adversarial_loss = torch.nn.BCELoss()
auxiliary_loss = torch.nn.CrossEntropyLoss()

# %%
# Initialize generator and discriminator
generator = Generator()
discriminator = Discriminator()

# %%
"""Se la GPU è disponibile spostiamo i modelli e le Loss all'interno della GPU"""
if cuda:
    generator.cuda()
    discriminator.cuda()
    adversarial_loss.cuda()
    auxiliary_loss.cuda()

# %%
#Inizializziamo i parametri dei moduli presenti all'interno del generatore e del discriminatore
"""Supponiamo di considerare la funzione apply invocata su generator. Tale funzione
in maniera iterativa prende ogni singolo modulo presente all'interno di generator
e lo passa come parametro della funzione weights_init_normal"""
generator.apply(weights_init_normal)
discriminator.apply(weights_init_normal)
# Out:
# Discriminator(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Dropout2d(p=0.2, inplace=False)
#     (6): BatchNorm2d(32, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): LeakyReLU(negative_slope=0.2, inplace=True)
#     (9): Dropout2d(p=0.2, inplace=False)
#     (10): BatchNorm2d(64, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (12): LeakyReLU(negative_slope=0.2, inplace=True)
#     (13): Dropout2d(p=0.2, inplace=False)
#     (14): BatchNorm2d(128, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (adv_layer): Sequential(
#     (0): Linear(in_features=512, out_features=1, bias=True)
#     (1): Sigmoid()
#   )
#   (aux_layer): Sequential(
#     (0): Linear(in_features=512, out_features=10, bias=True)
#     (1): Softmax(dim=None)
#   )
# )

# %%
# Configure data loader
os.makedirs("../../data/CIFAR10", exist_ok=True)
dataloader = torch.utils.data.DataLoader(
    datasets.CIFAR10(
        "../../data/CIFAR10",
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.Resize(opt.img_size), transforms.ToTensor(), transforms.Normalize([0.5], [0.5])]
        ),
    ),
    batch_size=opt.batch_size,
    shuffle=True,
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../../data/CIFAR10/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ../../data/CIFAR10/cifar-10-python.tar.gz to ../../data/CIFAR10

# %%
#Creiamo gli ottimizzatori
optimizer_G = torch.optim.Adam(generator.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2))

# %%
FloatTensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if cuda else torch.LongTensor

# %%
def sample_image(n_row, epoch):
    """Saves a grid of generated digits ranging from 0 to n_classes"""
    # Sample noise
    """Per generare z, ossia il minibatch contenente rumore casuale da mandare in ingresso
    al generatore abbiamo creato un Tensor 2-D avente un numero di righe pari a
    n_row**2 e un numero di colonne pari a 100. Dopodiché, dal momento che vogliamo
    che questo Tensor contenga sempre gli stessi valori anche se la funzione sample_image
    viene chiamata più volte abbiamo deciso di wrappare tale Tensor all'interno di Variable.
    Così facendo, anche se la funzione sample_image viene chiamata più volte, il valore di z
    rimane invariato"""
    z = Variable(FloatTensor(np.random.normal(0, 1, (n_row ** 2, opt.latent_dim))))
    # Get labels ranging from 0 to n_classes for n rows
    labels = np.array([num for _ in range(n_row) for num in range(n_row)])
    labels = Variable(LongTensor(labels))
    """Per generare labels, ossia il minibatch contenente i target da mandare in ingresso
    al generatore abbiamo creato un Tensor 1-D avente un numero di elementi pari a 100
    (numero di righe di z), dove l'elemento di indice 0 assume 0, l'elemento di indice 1 assume 1, l'elemento di indice 2 assume 2
    l'elemento di indice 9 assume 9, l'elemento di indice 10 assume 0, l'elemento di indice 11 assume 1 e così via.
    Inoltre, per far si che il valore di labels non cambi nonostante la funzione sample_image venga chiamata più volte abbiamo wrappato
    tale Tensor all'interno di Variable"""
    """Prendiamo il Tensor 2-D z e il Tensor 1-D labels e mandiamoli in ingresso al generatore"""
    gen_imgs = generator(z, labels)
    """Il numero di immmagini che vengono prodotte in uscita dal gneratore è pari a n_row**2"""
    save_image(gen_imgs.data, "results_images/Epoca%d.png" % epoch, nrow=n_row, normalize=True)
    """Tramite save_image all'interno della directory results_images che abbiamo creato
    precedentemente inseriamo una griglia costituita dalle n_row**2 immagini prodotte in uscita
    dal generatore disposte su n_row righe"""

# %%
for epoch in range(opt.n_epochs):
  history_d_minibatch_accuracy = []
  history_d_minibatch_loss = []
  history_g_minibatch_loss = []
  for i, (imgs, labels) in enumerate(dataloader):

        batch_size = imgs.shape[0] #64

        # Adversarial ground truths
        valid = Variable(FloatTensor(batch_size, 1).fill_(1.0), requires_grad=False)
        """valid è un Tensor 2-D avente un numero di righe pari a batch_size(64)
        e un numero di colonne pari a 1. Tale Tensor contiene tutti 1 e ci 
        serve per calcolare l'adversarial loss per le immagini reali
        """
        fake = Variable(FloatTensor(batch_size, 1).fill_(0.0), requires_grad=False)
        """fake è un Tensor 2-D avente un numero di righe pari a batch_size(64)
        e un numero di colonne pari a 1. Tale Tensor contiene tutti 0 e ci 
        serve per calcolare l'adversarial loss per le immagini fake
        """

        # Configure input
        """Invocando il metodo type su un Tensor è possibile effettuare il
        casting di tale Tensor"""
        real_imgs = Variable(imgs.type(FloatTensor))
        """real_imgs è un minibatch contenente un numero di immagini reali pari
        a minibatch_size(64)"""
        labels = Variable(labels.type(LongTensor))
        """labels è un minibatch contenente i minibatch_size(64) target
        corrispondenti alle 64 immagini reali presenti nel minibatch real_imgs"""

        # -----------------
        #  Train Generator
        # -----------------
        """Resettiamo il gradiente"""
        optimizer_G.zero_grad()

        # Sample noise and labels as generator input
        """z è un minibatch contenente 64 rumori casuali, ognuno di 100 elementi"""
        z = Variable(FloatTensor(np.random.normal(0, 1, (batch_size, opt.latent_dim))))
        """gen_labels è un Tensor 1-D contenente 64 (batch_size) target, uno per
        ogni singolo rumore casuale presente nel minibatch z"""
        gen_labels = Variable(LongTensor(np.random.randint(0, opt.n_classes, batch_size)))

        # Generate a batch of images
        gen_imgs = generator(z, gen_labels)
        """gen_imgs è un minibatch contenente le 64 immagini (batch_size)
        generate dal generatore"""
        # Loss measures generator's ability to fool the discriminator
        """A questo punto prendiamo il minibatch contenente le 64 immagini
        generate dal generatore e le mandiamo in ingresso al discriminatore"""
        validity, pred_label = discriminator(gen_imgs)
        g_loss = 0.5 * (adversarial_loss(validity, valid) + auxiliary_loss(pred_label, gen_labels))
        """Calcoliamo il gradiente della g_loss"""
        g_loss.backward()
        """Ottimizziamo i parametri del generatore"""
        optimizer_G.step()

        # ---------------------
        #  Train Discriminator
        # ---------------------
        """Resettiamo il gradiente"""
        optimizer_D.zero_grad()

        # Loss for real images
        real_pred, real_aux = discriminator(real_imgs)
        d_real_loss = (adversarial_loss(real_pred, valid) + auxiliary_loss(real_aux, labels)) / 2

        # Loss for fake images
        fake_pred, fake_aux = discriminator(gen_imgs.detach())
        """gen_imgs contiene le 64 (batch_size) immagini generate dal generatore
        durante la fase di training del generatore"""

        """Utilizzando detach() nel momento in cui attuiamo la backpropagation
        per aggiornare i parametri del discriminatore quello che accade è che
        effettivamente vengono aggiornati solo ed esclusivamente i parametri del
        discriminatore e non anche quelli del generatore.
        Se non usassimo detach() nel momento in cui attuaiamo la backpropagation
        per aggiornare i parametri del discriminatore, oltre ai parametri del
        discriminatore, verrebbero aggiornati anche quelli del generatore e questo
        non va bene in quanto vogliamo aggiornare solo i parametri del
        discriminatore"""
        d_fake_loss = (adversarial_loss(fake_pred, fake) + auxiliary_loss(fake_aux, gen_labels)) / 2

        # Total discriminator loss
        d_loss = (d_real_loss + d_fake_loss) / 2
        """Calcoliamo il gradiente della loss del discriminatore"""
        d_loss.backward()
        """Ottimizziamo i parametri del discriminatore"""
        optimizer_D.step()


        #Calcoliamo l'accuratezza del discriminatore nel classificare correttamente la classe di appartenenza di ogni singola immagine (fake o reale) che riceve
        pred = np.concatenate([real_aux.data.cpu().numpy(), fake_aux.data.cpu().numpy()], axis=0)
        """pred ha dimensione 128x10 in quanto è dato dalla concatenazione per riga
        di real_aux (Tensor 2-D di dimensione 64x10 contenente per ogni immagine reale fornita al discriminatore
        le probabilità con cui l'immagine appartiene ad ognuna delle 10 classi) e di
        fake_aux (Tensor 2-D di dimensione 64x10 contenente per ogni immagine fake fornita al discriminatore
        le probabilità con cui l'immagine appartiene ad ognuna delle 10 classi)"""
        target = np.concatenate([labels.data.cpu().numpy(), gen_labels.data.cpu().numpy()], axis=0)
        """target ha dimensione 128 in quanto è dato dalla concatenazione per riga
        di labels (Tensor 1-D di dimensione 64 contenente per ogni immagine reale fornita al discriminatore il relativo target)
        e di gen_labels (Tensor 1-D di dimensione 64 contenente per ogni immagine fake fornita al discriminatore il relativo target)
        """
        d_minibatch_accuracy = np.mean(np.argmax(pred, axis=1) == target)
        history_d_minibatch_accuracy.append(d_minibatch_accuracy)
        history_d_minibatch_loss.append(d_loss.item())
        history_g_minibatch_loss.append(g_loss.item())

        if (epoch+1) % opt.sample_interval == 0:
            sample_image(n_row=10, epoch=epoch+1)

  d_epoch_accuracy = np.mean(history_d_minibatch_accuracy)
  d_epoch_loss = np.mean(history_d_minibatch_loss)
  g_epoch_loss = np.mean(history_g_minibatch_loss)
  print(f"Epoch {epoch+1}: Discriminator_Loss={d_epoch_loss:.4f}, Discriminator_Accuracy={d_epoch_accuracy*100:.4f}, Generator_Loss={g_epoch_loss:.4f}")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch 1: Discriminator_Loss=1.4342, Discriminator_Accuracy=25.8202, Generator_Loss=1.4198
# Epoch 2: Discriminator_Loss=1.2722, Discriminator_Accuracy=59.5189, Generator_Loss=1.1660
# Epoch 3: Discriminator_Loss=1.2613, Discriminator_Accuracy=62.2083, Generator_Loss=1.1323
# Epoch 4: Discriminator_Loss=1.2566, Discriminator_Accuracy=63.1664, Generator_Loss=1.1211
# Epoch 5: Discriminator_Loss=1.2523, Discriminator_Accuracy=63.9976, Generator_Loss=1.1200
# Epoch 6: Discriminator_Loss=1.2501, Discriminator_Accuracy=64.4851, Generator_Loss=1.1172
# Epoch 7: Discriminator_Loss=1.2463, Discriminator_Accuracy=65.1495, Generator_Loss=1.1160
# Epoch 8: Discriminator_Loss=1.2441, Discriminator_Accuracy=65.7049, Generator_Loss=1.1128
# Epoch 9: Discriminator_Loss=1.2417, Discriminator_Accuracy=66.2704, Generator_Loss=1.1127
# Epoch 10: Discriminator_Loss=1.2392, Discriminator_Accuracy=66.7469, Generator_Loss=1.1101
# Epoch 11: Discriminator_Loss=1.2376, Discriminator_Accuracy=67.0027, Generator_Loss=1.1109
# Epoch 12: Discriminator_Loss=1.2353, Discriminator_Accuracy=67.5012, Generator_Loss=1.1096
# Epoch 13: Discriminator_Loss=1.2337, Discriminator_Accuracy=67.9358, Generator_Loss=1.1087
# Epoch 14: Discriminator_Loss=1.2327, Discriminator_Accuracy=68.2035, Generator_Loss=1.1079
# Epoch 15: Discriminator_Loss=1.2298, Discriminator_Accuracy=68.5752, Generator_Loss=1.1064
# Epoch 16: Discriminator_Loss=1.2282, Discriminator_Accuracy=68.8999, Generator_Loss=1.1076
# Epoch 17: Discriminator_Loss=1.2275, Discriminator_Accuracy=68.9858, Generator_Loss=1.1074
# Epoch 18: Discriminator_Loss=1.2262, Discriminator_Accuracy=69.2335, Generator_Loss=1.1070
# Epoch 19: Discriminator_Loss=1.2248, Discriminator_Accuracy=69.4643, Generator_Loss=1.1069
# Epoch 20: Discriminator_Loss=1.2241, Discriminator_Accuracy=69.7780, Generator_Loss=1.1067
# Epoch 21: Discriminator_Loss=1.2235, Discriminator_Accuracy=70.0338, Generator_Loss=1.1061
# Epoch 22: Discriminator_Loss=1.2213, Discriminator_Accuracy=70.3275, Generator_Loss=1.1050
# Epoch 23: Discriminator_Loss=1.2207, Discriminator_Accuracy=70.5723, Generator_Loss=1.1064
# Epoch 24: Discriminator_Loss=1.2199, Discriminator_Accuracy=70.6582, Generator_Loss=1.1056
# Epoch 25: Discriminator_Loss=1.2191, Discriminator_Accuracy=70.8290, Generator_Loss=1.1058
# Epoch 26: Discriminator_Loss=1.2181, Discriminator_Accuracy=71.1067, Generator_Loss=1.1052
# Epoch 27: Discriminator_Loss=1.2168, Discriminator_Accuracy=71.3415, Generator_Loss=1.1052
# Epoch 28: Discriminator_Loss=1.2159, Discriminator_Accuracy=71.3535, Generator_Loss=1.1047
# Epoch 29: Discriminator_Loss=1.2158, Discriminator_Accuracy=71.4754, Generator_Loss=1.1057
# Epoch 30: Discriminator_Loss=1.2153, Discriminator_Accuracy=71.6152, Generator_Loss=1.1041
# Epoch 31: Discriminator_Loss=1.2148, Discriminator_Accuracy=71.8101, Generator_Loss=1.1055
# Epoch 32: Discriminator_Loss=1.2142, Discriminator_Accuracy=72.0139, Generator_Loss=1.1037
# Epoch 33: Discriminator_Loss=1.2132, Discriminator_Accuracy=72.1687, Generator_Loss=1.1039
# Epoch 34: Discriminator_Loss=1.2115, Discriminator_Accuracy=72.3216, Generator_Loss=1.1043
# Epoch 35: Discriminator_Loss=1.2116, Discriminator_Accuracy=72.3166, Generator_Loss=1.1048
# Epoch 36: Discriminator_Loss=1.2105, Discriminator_Accuracy=72.6213, Generator_Loss=1.1044
# Epoch 37: Discriminator_Loss=1.2104, Discriminator_Accuracy=72.5983, Generator_Loss=1.1042
# Epoch 38: Discriminator_Loss=1.2097, Discriminator_Accuracy=72.7901, Generator_Loss=1.1037
# Epoch 39: Discriminator_Loss=1.2087, Discriminator_Accuracy=72.8491, Generator_Loss=1.1042
# Epoch 40: Discriminator_Loss=1.2084, Discriminator_Accuracy=73.0619, Generator_Loss=1.1057
# Epoch 41: Discriminator_Loss=1.2083, Discriminator_Accuracy=72.9480, Generator_Loss=1.1040
# Epoch 42: Discriminator_Loss=1.2077, Discriminator_Accuracy=73.2467, Generator_Loss=1.1031
# Epoch 43: Discriminator_Loss=1.2071, Discriminator_Accuracy=73.2087, Generator_Loss=1.1038
# Epoch 44: Discriminator_Loss=1.2068, Discriminator_Accuracy=73.3776, Generator_Loss=1.1023
# Epoch 45: Discriminator_Loss=1.2065, Discriminator_Accuracy=73.3875, Generator_Loss=1.1042
# Epoch 46: Discriminator_Loss=1.2056, Discriminator_Accuracy=73.6053, Generator_Loss=1.1027
# Epoch 47: Discriminator_Loss=1.2051, Discriminator_Accuracy=73.6743, Generator_Loss=1.1026
# Epoch 48: Discriminator_Loss=1.2044, Discriminator_Accuracy=73.8461, Generator_Loss=1.1020
# Epoch 49: Discriminator_Loss=1.2033, Discriminator_Accuracy=73.9260, Generator_Loss=1.1029
# Epoch 50: Discriminator_Loss=1.2038, Discriminator_Accuracy=73.9340, Generator_Loss=1.1012
# Epoch 51: Discriminator_Loss=1.2037, Discriminator_Accuracy=74.1218, Generator_Loss=1.1021
# Epoch 52: Discriminator_Loss=1.2029, Discriminator_Accuracy=74.1678, Generator_Loss=1.1017
# Epoch 53: Discriminator_Loss=1.2030, Discriminator_Accuracy=74.2907, Generator_Loss=1.1018
# Epoch 54: Discriminator_Loss=1.2024, Discriminator_Accuracy=74.3496, Generator_Loss=1.1007
# Epoch 55: Discriminator_Loss=1.2019, Discriminator_Accuracy=74.4116, Generator_Loss=1.1013
# Epoch 56: Discriminator_Loss=1.1999, Discriminator_Accuracy=74.6933, Generator_Loss=1.1012
# Epoch 57: Discriminator_Loss=1.2024, Discriminator_Accuracy=74.4106, Generator_Loss=1.1022
# Epoch 58: Discriminator_Loss=1.2005, Discriminator_Accuracy=74.6703, Generator_Loss=1.0994
# Epoch 59: Discriminator_Loss=1.2006, Discriminator_Accuracy=74.7822, Generator_Loss=1.1013
# Epoch 60: Discriminator_Loss=1.2011, Discriminator_Accuracy=74.6813, Generator_Loss=1.0997
# Epoch 61: Discriminator_Loss=1.1993, Discriminator_Accuracy=74.9211, Generator_Loss=1.1002
# Epoch 62: Discriminator_Loss=1.1999, Discriminator_Accuracy=74.8122, Generator_Loss=1.1001
# Epoch 63: Discriminator_Loss=1.1992, Discriminator_Accuracy=74.9510, Generator_Loss=1.1008
# Epoch 64: Discriminator_Loss=1.1981, Discriminator_Accuracy=75.0629, Generator_Loss=1.1006
# Epoch 65: Discriminator_Loss=1.1983, Discriminator_Accuracy=75.1948, Generator_Loss=1.0990
# Epoch 66: Discriminator_Loss=1.1983, Discriminator_Accuracy=75.1169, Generator_Loss=1.0994
# Epoch 67: Discriminator_Loss=1.1974, Discriminator_Accuracy=75.3357, Generator_Loss=1.0989
# Epoch 68: Discriminator_Loss=1.1981, Discriminator_Accuracy=75.3726, Generator_Loss=1.0984
# Epoch 69: Discriminator_Loss=1.1981, Discriminator_Accuracy=75.3886, Generator_Loss=1.0981
# Epoch 70: Discriminator_Loss=1.1973, Discriminator_Accuracy=75.3786, Generator_Loss=1.0977
# Epoch 71: Discriminator_Loss=1.1969, Discriminator_Accuracy=75.3906, Generator_Loss=1.0977
# Epoch 72: Discriminator_Loss=1.1958, Discriminator_Accuracy=75.6444, Generator_Loss=1.0981
# Epoch 73: Discriminator_Loss=1.1964, Discriminator_Accuracy=75.5585, Generator_Loss=1.0983
# Epoch 74: Discriminator_Loss=1.1962, Discriminator_Accuracy=75.6034, Generator_Loss=1.0976
# Epoch 75: Discriminator_Loss=1.1956, Discriminator_Accuracy=75.6983, Generator_Loss=1.0977
# Epoch 76: Discriminator_Loss=1.1955, Discriminator_Accuracy=75.7892, Generator_Loss=1.0993
# Epoch 77: Discriminator_Loss=1.1960, Discriminator_Accuracy=75.7683, Generator_Loss=1.0966
# Epoch 78: Discriminator_Loss=1.1955, Discriminator_Accuracy=75.8242, Generator_Loss=1.0971
# Epoch 79: Discriminator_Loss=1.1955, Discriminator_Accuracy=75.8642, Generator_Loss=1.0964
# Epoch 80: Discriminator_Loss=1.1950, Discriminator_Accuracy=75.8792, Generator_Loss=1.0961
# Epoch 81: Discriminator_Loss=1.1949, Discriminator_Accuracy=76.0060, Generator_Loss=1.0967
# Epoch 82: Discriminator_Loss=1.1937, Discriminator_Accuracy=76.1039, Generator_Loss=1.0964
# Epoch 83: Discriminator_Loss=1.1944, Discriminator_Accuracy=76.1449, Generator_Loss=1.0977
# Epoch 84: Discriminator_Loss=1.1936, Discriminator_Accuracy=76.1959, Generator_Loss=1.0965
# Epoch 85: Discriminator_Loss=1.1936, Discriminator_Accuracy=76.3187, Generator_Loss=1.0974
# Epoch 86: Discriminator_Loss=1.1942, Discriminator_Accuracy=76.2288, Generator_Loss=1.0953
# Epoch 87: Discriminator_Loss=1.1931, Discriminator_Accuracy=76.1199, Generator_Loss=1.0948
# Epoch 88: Discriminator_Loss=1.1929, Discriminator_Accuracy=76.3377, Generator_Loss=1.0967
# Epoch 89: Discriminator_Loss=1.1944, Discriminator_Accuracy=76.1409, Generator_Loss=1.0952
# Epoch 90: Discriminator_Loss=1.1936, Discriminator_Accuracy=76.2058, Generator_Loss=1.0952
# Epoch 91: Discriminator_Loss=1.1939, Discriminator_Accuracy=76.2158, Generator_Loss=1.0943
# Epoch 92: Discriminator_Loss=1.1924, Discriminator_Accuracy=76.3177, Generator_Loss=1.0955
# Epoch 93: Discriminator_Loss=1.1931, Discriminator_Accuracy=76.3577, Generator_Loss=1.0962
# Epoch 94: Discriminator_Loss=1.1914, Discriminator_Accuracy=76.6015, Generator_Loss=1.0944
# Epoch 95: Discriminator_Loss=1.1921, Discriminator_Accuracy=76.5505, Generator_Loss=1.0944
# Epoch 96: Discriminator_Loss=1.1920, Discriminator_Accuracy=76.5715, Generator_Loss=1.0951
# Epoch 97: Discriminator_Loss=1.1903, Discriminator_Accuracy=76.7363, Generator_Loss=1.0957
# Epoch 98: Discriminator_Loss=1.1909, Discriminator_Accuracy=76.7813, Generator_Loss=1.0953
# Epoch 99: Discriminator_Loss=1.1913, Discriminator_Accuracy=76.7493, Generator_Loss=1.0955
# Epoch 100: Discriminator_Loss=1.1910, Discriminator_Accuracy=76.7833, Generator_Loss=1.0933
# Epoch 101: Discriminator_Loss=1.1915, Discriminator_Accuracy=76.6994, Generator_Loss=1.0937
# Epoch 102: Discriminator_Loss=1.1907, Discriminator_Accuracy=76.7114, Generator_Loss=1.0942
# Epoch 103: Discriminator_Loss=1.1900, Discriminator_Accuracy=76.7873, Generator_Loss=1.0959
# Epoch 104: Discriminator_Loss=1.1906, Discriminator_Accuracy=76.8402, Generator_Loss=1.0948
# Epoch 105: Discriminator_Loss=1.1907, Discriminator_Accuracy=76.9082, Generator_Loss=1.0937
# Epoch 106: Discriminator_Loss=1.1906, Discriminator_Accuracy=76.8652, Generator_Loss=1.0947
# Epoch 107: Discriminator_Loss=1.1895, Discriminator_Accuracy=77.0700, Generator_Loss=1.0937
# Epoch 108: Discriminator_Loss=1.1902, Discriminator_Accuracy=77.0261, Generator_Loss=1.0930
# Epoch 109: Discriminator_Loss=1.1897, Discriminator_Accuracy=77.2269, Generator_Loss=1.0924
# Epoch 110: Discriminator_Loss=1.1884, Discriminator_Accuracy=77.2369, Generator_Loss=1.0934
# Epoch 111: Discriminator_Loss=1.1896, Discriminator_Accuracy=77.2349, Generator_Loss=1.0926
# Epoch 112: Discriminator_Loss=1.1892, Discriminator_Accuracy=77.1859, Generator_Loss=1.0920
# Epoch 113: Discriminator_Loss=1.1886, Discriminator_Accuracy=77.2918, Generator_Loss=1.0923
# Epoch 114: Discriminator_Loss=1.1889, Discriminator_Accuracy=77.2648, Generator_Loss=1.0920
# Epoch 115: Discriminator_Loss=1.1884, Discriminator_Accuracy=77.4367, Generator_Loss=1.0925
# Epoch 116: Discriminator_Loss=1.1884, Discriminator_Accuracy=77.4646, Generator_Loss=1.0913
# Epoch 117: Discriminator_Loss=1.1882, Discriminator_Accuracy=77.4836, Generator_Loss=1.0919
# Epoch 118: Discriminator_Loss=1.1879, Discriminator_Accuracy=77.4307, Generator_Loss=1.0916
# Epoch 119: Discriminator_Loss=1.1870, Discriminator_Accuracy=77.4646, Generator_Loss=1.0926
# Epoch 120: Discriminator_Loss=1.1874, Discriminator_Accuracy=77.4826, Generator_Loss=1.0933
# Epoch 121: Discriminator_Loss=1.1869, Discriminator_Accuracy=77.6674, Generator_Loss=1.0922
# Epoch 122: Discriminator_Loss=1.1867, Discriminator_Accuracy=77.6624, Generator_Loss=1.0930
# Epoch 123: Discriminator_Loss=1.1871, Discriminator_Accuracy=77.5705, Generator_Loss=1.0939
# Epoch 124: Discriminator_Loss=1.1867, Discriminator_Accuracy=77.7643, Generator_Loss=1.0913
# Epoch 125: Discriminator_Loss=1.1853, Discriminator_Accuracy=77.8872, Generator_Loss=1.0918
# Epoch 126: Discriminator_Loss=1.1863, Discriminator_Accuracy=77.6964, Generator_Loss=1.0925
# Epoch 127: Discriminator_Loss=1.1867, Discriminator_Accuracy=77.7524, Generator_Loss=1.0927
# Epoch 128: Discriminator_Loss=1.1862, Discriminator_Accuracy=77.8003, Generator_Loss=1.0915
# Epoch 129: Discriminator_Loss=1.1865, Discriminator_Accuracy=77.7813, Generator_Loss=1.0927
# Epoch 130: Discriminator_Loss=1.1862, Discriminator_Accuracy=77.8143, Generator_Loss=1.0927
# Epoch 131: Discriminator_Loss=1.1858, Discriminator_Accuracy=77.9382, Generator_Loss=1.0912
# Epoch 132: Discriminator_Loss=1.1863, Discriminator_Accuracy=77.8243, Generator_Loss=1.0918
# Epoch 133: Discriminator_Loss=1.1861, Discriminator_Accuracy=77.8523, Generator_Loss=1.0915
# Epoch 134: Discriminator_Loss=1.1857, Discriminator_Accuracy=78.0021, Generator_Loss=1.0918
# Epoch 135: Discriminator_Loss=1.1851, Discriminator_Accuracy=77.9212, Generator_Loss=1.0909
# Epoch 136: Discriminator_Loss=1.1851, Discriminator_Accuracy=78.0401, Generator_Loss=1.0916
# Epoch 137: Discriminator_Loss=1.1849, Discriminator_Accuracy=78.0481, Generator_Loss=1.0914
# Epoch 138: Discriminator_Loss=1.1854, Discriminator_Accuracy=77.9522, Generator_Loss=1.0909
# Epoch 139: Discriminator_Loss=1.1857, Discriminator_Accuracy=77.9072, Generator_Loss=1.0921
# Epoch 140: Discriminator_Loss=1.1851, Discriminator_Accuracy=78.1090, Generator_Loss=1.0905
# Epoch 141: Discriminator_Loss=1.1851, Discriminator_Accuracy=78.1690, Generator_Loss=1.0908
# Epoch 142: Discriminator_Loss=1.1842, Discriminator_Accuracy=78.2409, Generator_Loss=1.0898
# Epoch 143: Discriminator_Loss=1.1844, Discriminator_Accuracy=78.2159, Generator_Loss=1.0892
# Epoch 144: Discriminator_Loss=1.1847, Discriminator_Accuracy=78.1550, Generator_Loss=1.0901
# Epoch 145: Discriminator_Loss=1.1849, Discriminator_Accuracy=78.0431, Generator_Loss=1.0904
# Epoch 146: Discriminator_Loss=1.1839, Discriminator_Accuracy=78.2189, Generator_Loss=1.0894
# Epoch 147: Discriminator_Loss=1.1840, Discriminator_Accuracy=78.2858, Generator_Loss=1.0902
# Epoch 148: Discriminator_Loss=1.1841, Discriminator_Accuracy=78.1320, Generator_Loss=1.0893
# Epoch 149: Discriminator_Loss=1.1826, Discriminator_Accuracy=78.4257, Generator_Loss=1.0904
# Epoch 150: Discriminator_Loss=1.1836, Discriminator_Accuracy=78.3428, Generator_Loss=1.0914
# Epoch 151: Discriminator_Loss=1.1843, Discriminator_Accuracy=78.3468, Generator_Loss=1.0906
# Epoch 152: Discriminator_Loss=1.1830, Discriminator_Accuracy=78.4946, Generator_Loss=1.0904
# Epoch 153: Discriminator_Loss=1.1831, Discriminator_Accuracy=78.4587, Generator_Loss=1.0898
# Epoch 154: Discriminator_Loss=1.1834, Discriminator_Accuracy=78.4307, Generator_Loss=1.0897
# Epoch 155: Discriminator_Loss=1.1836, Discriminator_Accuracy=78.3768, Generator_Loss=1.0897
# Epoch 156: Discriminator_Loss=1.1834, Discriminator_Accuracy=78.5016, Generator_Loss=1.0894
# Epoch 157: Discriminator_Loss=1.1834, Discriminator_Accuracy=78.4387, Generator_Loss=1.0897
# Epoch 158: Discriminator_Loss=1.1830, Discriminator_Accuracy=78.4767, Generator_Loss=1.0902
# Epoch 159: Discriminator_Loss=1.1831, Discriminator_Accuracy=78.4207, Generator_Loss=1.0910
# Epoch 160: Discriminator_Loss=1.1823, Discriminator_Accuracy=78.6075, Generator_Loss=1.0903
# Epoch 161: Discriminator_Loss=1.1830, Discriminator_Accuracy=78.4677, Generator_Loss=1.0892
# Epoch 162: Discriminator_Loss=1.1825, Discriminator_Accuracy=78.5396, Generator_Loss=1.0892
# Epoch 163: Discriminator_Loss=1.1821, Discriminator_Accuracy=78.5776, Generator_Loss=1.0897
# Epoch 164: Discriminator_Loss=1.1826, Discriminator_Accuracy=78.5166, Generator_Loss=1.0903
# Epoch 165: Discriminator_Loss=1.1825, Discriminator_Accuracy=78.6345, Generator_Loss=1.0903
# Epoch 166: Discriminator_Loss=1.1819, Discriminator_Accuracy=78.6615, Generator_Loss=1.0908
# Epoch 167: Discriminator_Loss=1.1815, Discriminator_Accuracy=78.6835, Generator_Loss=1.0907
# Epoch 168: Discriminator_Loss=1.1831, Discriminator_Accuracy=78.5706, Generator_Loss=1.0897
# Epoch 169: Discriminator_Loss=1.1820, Discriminator_Accuracy=78.7244, Generator_Loss=1.0893
# Epoch 170: Discriminator_Loss=1.1818, Discriminator_Accuracy=78.6984, Generator_Loss=1.0903
# Epoch 171: Discriminator_Loss=1.1815, Discriminator_Accuracy=78.6905, Generator_Loss=1.0894
# Epoch 172: Discriminator_Loss=1.1819, Discriminator_Accuracy=78.7454, Generator_Loss=1.0901
# Epoch 173: Discriminator_Loss=1.1823, Discriminator_Accuracy=78.7194, Generator_Loss=1.0902
# Epoch 174: Discriminator_Loss=1.1811, Discriminator_Accuracy=78.8004, Generator_Loss=1.0896
# Epoch 175: Discriminator_Loss=1.1822, Discriminator_Accuracy=78.6595, Generator_Loss=1.0897
# Epoch 176: Discriminator_Loss=1.1812, Discriminator_Accuracy=78.8173, Generator_Loss=1.0902
# Epoch 177: Discriminator_Loss=1.1814, Discriminator_Accuracy=78.7964, Generator_Loss=1.0902
# Epoch 178: Discriminator_Loss=1.1818, Discriminator_Accuracy=78.7034, Generator_Loss=1.0893
# Epoch 179: Discriminator_Loss=1.1807, Discriminator_Accuracy=78.9932, Generator_Loss=1.0895
# Epoch 180: Discriminator_Loss=1.1825, Discriminator_Accuracy=78.6165, Generator_Loss=1.0906
# Epoch 181: Discriminator_Loss=1.1804, Discriminator_Accuracy=78.8553, Generator_Loss=1.0904
# Epoch 182: Discriminator_Loss=1.1816, Discriminator_Accuracy=78.6945, Generator_Loss=1.0901
# Epoch 183: Discriminator_Loss=1.1818, Discriminator_Accuracy=78.7714, Generator_Loss=1.0888
# Epoch 184: Discriminator_Loss=1.1808, Discriminator_Accuracy=78.8893, Generator_Loss=1.0903
# Epoch 185: Discriminator_Loss=1.1816, Discriminator_Accuracy=78.8543, Generator_Loss=1.0892
# Epoch 186: Discriminator_Loss=1.1809, Discriminator_Accuracy=78.9872, Generator_Loss=1.0885
# Epoch 187: Discriminator_Loss=1.1813, Discriminator_Accuracy=78.8843, Generator_Loss=1.0887
# Epoch 188: Discriminator_Loss=1.1814, Discriminator_Accuracy=78.8843, Generator_Loss=1.0891
# Epoch 189: Discriminator_Loss=1.1799, Discriminator_Accuracy=79.1210, Generator_Loss=1.0896
# Epoch 190: Discriminator_Loss=1.1799, Discriminator_Accuracy=79.0741, Generator_Loss=1.0894
# Epoch 191: Discriminator_Loss=1.1791, Discriminator_Accuracy=79.0201, Generator_Loss=1.0903
# Epoch 192: Discriminator_Loss=1.1798, Discriminator_Accuracy=78.9332, Generator_Loss=1.0922
# Epoch 193: Discriminator_Loss=1.1800, Discriminator_Accuracy=79.1091, Generator_Loss=1.0908
# Epoch 194: Discriminator_Loss=1.1798, Discriminator_Accuracy=79.1160, Generator_Loss=1.0910
# Epoch 195: Discriminator_Loss=1.1803, Discriminator_Accuracy=79.0111, Generator_Loss=1.0898
# Epoch 196: Discriminator_Loss=1.1800, Discriminator_Accuracy=78.9762, Generator_Loss=1.0899
# Epoch 197: Discriminator_Loss=1.1806, Discriminator_Accuracy=78.9322, Generator_Loss=1.0901
# Epoch 198: Discriminator_Loss=1.1798, Discriminator_Accuracy=79.0401, Generator_Loss=1.0901
# Epoch 199: Discriminator_Loss=1.1793, Discriminator_Accuracy=79.1990, Generator_Loss=1.0913
# Epoch 200: Discriminator_Loss=1.1804, Discriminator_Accuracy=78.9822, Generator_Loss=1.0892
# Epoch 201: Discriminator_Loss=1.1793, Discriminator_Accuracy=79.1310, Generator_Loss=1.0899
# Epoch 202: Discriminator_Loss=1.1804, Discriminator_Accuracy=79.1071, Generator_Loss=1.0895
# Epoch 203: Discriminator_Loss=1.1802, Discriminator_Accuracy=79.1480, Generator_Loss=1.0892
# Epoch 204: Discriminator_Loss=1.1801, Discriminator_Accuracy=79.0901, Generator_Loss=1.0884
# Epoch 205: Discriminator_Loss=1.1800, Discriminator_Accuracy=79.1460, Generator_Loss=1.0904
# Epoch 206: Discriminator_Loss=1.1795, Discriminator_Accuracy=79.1970, Generator_Loss=1.0896
# Epoch 207: Discriminator_Loss=1.1794, Discriminator_Accuracy=79.2219, Generator_Loss=1.0893
# Epoch 208: Discriminator_Loss=1.1797, Discriminator_Accuracy=79.2539, Generator_Loss=1.0887
# Epoch 209: Discriminator_Loss=1.1796, Discriminator_Accuracy=79.2309, Generator_Loss=1.0889
# Epoch 210: Discriminator_Loss=1.1788, Discriminator_Accuracy=79.3029, Generator_Loss=1.0885
# Epoch 211: Discriminator_Loss=1.1787, Discriminator_Accuracy=79.3488, Generator_Loss=1.0893
# Epoch 212: Discriminator_Loss=1.1803, Discriminator_Accuracy=79.1240, Generator_Loss=1.0885
# Epoch 213: Discriminator_Loss=1.1785, Discriminator_Accuracy=79.3948, Generator_Loss=1.0889
# Epoch 214: Discriminator_Loss=1.1800, Discriminator_Accuracy=79.2030, Generator_Loss=1.0887
# Epoch 215: Discriminator_Loss=1.1798, Discriminator_Accuracy=79.1980, Generator_Loss=1.0887
# Epoch 216: Discriminator_Loss=1.1789, Discriminator_Accuracy=79.2819, Generator_Loss=1.0893
# Epoch 217: Discriminator_Loss=1.1795, Discriminator_Accuracy=79.3009, Generator_Loss=1.0888
# Epoch 218: Discriminator_Loss=1.1790, Discriminator_Accuracy=79.2699, Generator_Loss=1.0888
# Epoch 219: Discriminator_Loss=1.1783, Discriminator_Accuracy=79.4657, Generator_Loss=1.0877
# Epoch 220: Discriminator_Loss=1.1789, Discriminator_Accuracy=79.3099, Generator_Loss=1.0875
# Epoch 221: Discriminator_Loss=1.1786, Discriminator_Accuracy=79.4238, Generator_Loss=1.0893
# Epoch 222: Discriminator_Loss=1.1797, Discriminator_Accuracy=79.3219, Generator_Loss=1.0880
# Epoch 223: Discriminator_Loss=1.1788, Discriminator_Accuracy=79.4238, Generator_Loss=1.0881
# Epoch 224: Discriminator_Loss=1.1779, Discriminator_Accuracy=79.4637, Generator_Loss=1.0878
# Epoch 225: Discriminator_Loss=1.1788, Discriminator_Accuracy=79.4268, Generator_Loss=1.0892
# Epoch 226: Discriminator_Loss=1.1778, Discriminator_Accuracy=79.5077, Generator_Loss=1.0882
# Epoch 227: Discriminator_Loss=1.1772, Discriminator_Accuracy=79.5526, Generator_Loss=1.0878
# Epoch 228: Discriminator_Loss=1.1778, Discriminator_Accuracy=79.6266, Generator_Loss=1.0886
# Epoch 229: Discriminator_Loss=1.1773, Discriminator_Accuracy=79.4927, Generator_Loss=1.0889
# Epoch 230: Discriminator_Loss=1.1783, Discriminator_Accuracy=79.5017, Generator_Loss=1.0884
# Epoch 231: Discriminator_Loss=1.1782, Discriminator_Accuracy=79.5496, Generator_Loss=1.0871
# Epoch 232: Discriminator_Loss=1.1787, Discriminator_Accuracy=79.4877, Generator_Loss=1.0885
# Epoch 233: Discriminator_Loss=1.1780, Discriminator_Accuracy=79.6865, Generator_Loss=1.0871
# Epoch 234: Discriminator_Loss=1.1773, Discriminator_Accuracy=79.6695, Generator_Loss=1.0863
# Epoch 235: Discriminator_Loss=1.1774, Discriminator_Accuracy=79.6375, Generator_Loss=1.0881
# Epoch 236: Discriminator_Loss=1.1773, Discriminator_Accuracy=79.8284, Generator_Loss=1.0868
# Epoch 237: Discriminator_Loss=1.1772, Discriminator_Accuracy=79.6765, Generator_Loss=1.0882
# Epoch 238: Discriminator_Loss=1.1770, Discriminator_Accuracy=79.7105, Generator_Loss=1.0869
# Epoch 239: Discriminator_Loss=1.1776, Discriminator_Accuracy=79.7265, Generator_Loss=1.0883
# Epoch 240: Discriminator_Loss=1.1776, Discriminator_Accuracy=79.7285, Generator_Loss=1.0870
# Epoch 241: Discriminator_Loss=1.1773, Discriminator_Accuracy=79.5476, Generator_Loss=1.0884
# Epoch 242: Discriminator_Loss=1.1772, Discriminator_Accuracy=79.6665, Generator_Loss=1.0891
# Epoch 243: Discriminator_Loss=1.1763, Discriminator_Accuracy=79.8344, Generator_Loss=1.0873
# Epoch 244: Discriminator_Loss=1.1765, Discriminator_Accuracy=79.9113, Generator_Loss=1.0876
# Epoch 245: Discriminator_Loss=1.1768, Discriminator_Accuracy=79.7804, Generator_Loss=1.0886
# Epoch 246: Discriminator_Loss=1.1774, Discriminator_Accuracy=79.6875, Generator_Loss=1.0878
# Epoch 247: Discriminator_Loss=1.1757, Discriminator_Accuracy=79.8803, Generator_Loss=1.0865
# Epoch 248: Discriminator_Loss=1.1767, Discriminator_Accuracy=79.7085, Generator_Loss=1.0874
# Epoch 249: Discriminator_Loss=1.1776, Discriminator_Accuracy=79.6855, Generator_Loss=1.0880
# Epoch 250: Discriminator_Loss=1.1763, Discriminator_Accuracy=79.8054, Generator_Loss=1.0876
# Epoch 251: Discriminator_Loss=1.1763, Discriminator_Accuracy=79.7964, Generator_Loss=1.0885
# Epoch 252: Discriminator_Loss=1.1755, Discriminator_Accuracy=79.8863, Generator_Loss=1.0890
# Epoch 253: Discriminator_Loss=1.1764, Discriminator_Accuracy=79.8933, Generator_Loss=1.0876
# Epoch 254: Discriminator_Loss=1.1760, Discriminator_Accuracy=79.9333, Generator_Loss=1.0882
# Epoch 255: Discriminator_Loss=1.1763, Discriminator_Accuracy=79.8473, Generator_Loss=1.0872
# Epoch 256: Discriminator_Loss=1.1768, Discriminator_Accuracy=79.8304, Generator_Loss=1.0871
# Epoch 257: Discriminator_Loss=1.1763, Discriminator_Accuracy=79.8573, Generator_Loss=1.0877
# Epoch 258: Discriminator_Loss=1.1760, Discriminator_Accuracy=79.9023, Generator_Loss=1.0881
# Epoch 259: Discriminator_Loss=1.1766, Discriminator_Accuracy=79.8214, Generator_Loss=1.0868
# Epoch 260: Discriminator_Loss=1.1760, Discriminator_Accuracy=79.8643, Generator_Loss=1.0876
# Epoch 261: Discriminator_Loss=1.1756, Discriminator_Accuracy=79.9642, Generator_Loss=1.0879
# Epoch 262: Discriminator_Loss=1.1765, Discriminator_Accuracy=79.8763, Generator_Loss=1.0874
# Epoch 263: Discriminator_Loss=1.1766, Discriminator_Accuracy=79.7824, Generator_Loss=1.0879
# Epoch 264: Discriminator_Loss=1.1764, Discriminator_Accuracy=79.9233, Generator_Loss=1.0876
# Epoch 265: Discriminator_Loss=1.1754, Discriminator_Accuracy=79.9922, Generator_Loss=1.0848
# Epoch 266: Discriminator_Loss=1.1763, Discriminator_Accuracy=80.0162, Generator_Loss=1.0865
# Epoch 267: Discriminator_Loss=1.1751, Discriminator_Accuracy=79.9133, Generator_Loss=1.0882
# Epoch 268: Discriminator_Loss=1.1755, Discriminator_Accuracy=79.9822, Generator_Loss=1.0883
# Epoch 269: Discriminator_Loss=1.1752, Discriminator_Accuracy=80.0631, Generator_Loss=1.0897
# Epoch 270: Discriminator_Loss=1.1751, Discriminator_Accuracy=80.0062, Generator_Loss=1.0880
# Epoch 271: Discriminator_Loss=1.1744, Discriminator_Accuracy=79.9712, Generator_Loss=1.0897
# Epoch 272: Discriminator_Loss=1.1753, Discriminator_Accuracy=79.9453, Generator_Loss=1.0886
# Epoch 273: Discriminator_Loss=1.1756, Discriminator_Accuracy=79.9043, Generator_Loss=1.0884
# Epoch 274: Discriminator_Loss=1.1746, Discriminator_Accuracy=80.0611, Generator_Loss=1.0881
# Epoch 275: Discriminator_Loss=1.1755, Discriminator_Accuracy=79.9962, Generator_Loss=1.0899
# Epoch 276: Discriminator_Loss=1.1750, Discriminator_Accuracy=79.9612, Generator_Loss=1.0890
# Epoch 277: Discriminator_Loss=1.1751, Discriminator_Accuracy=80.0462, Generator_Loss=1.0899
# Epoch 278: Discriminator_Loss=1.1754, Discriminator_Accuracy=80.0691, Generator_Loss=1.0888
# Epoch 279: Discriminator_Loss=1.1752, Discriminator_Accuracy=80.1780, Generator_Loss=1.0881
# Epoch 280: Discriminator_Loss=1.1756, Discriminator_Accuracy=80.0621, Generator_Loss=1.0881
# Epoch 281: Discriminator_Loss=1.1747, Discriminator_Accuracy=80.1770, Generator_Loss=1.0892
# Epoch 282: Discriminator_Loss=1.1753, Discriminator_Accuracy=80.0132, Generator_Loss=1.0904
# Epoch 283: Discriminator_Loss=1.1757, Discriminator_Accuracy=80.0192, Generator_Loss=1.0884
# Epoch 284: Discriminator_Loss=1.1752, Discriminator_Accuracy=80.1121, Generator_Loss=1.0891
# Epoch 285: Discriminator_Loss=1.1748, Discriminator_Accuracy=80.2400, Generator_Loss=1.0874
# Epoch 286: Discriminator_Loss=1.1753, Discriminator_Accuracy=80.1371, Generator_Loss=1.0891
# Epoch 287: Discriminator_Loss=1.1743, Discriminator_Accuracy=80.1371, Generator_Loss=1.0878
# Epoch 288: Discriminator_Loss=1.1743, Discriminator_Accuracy=80.2689, Generator_Loss=1.0877
# Epoch 289: Discriminator_Loss=1.1753, Discriminator_Accuracy=80.1481, Generator_Loss=1.0879
# Epoch 290: Discriminator_Loss=1.1737, Discriminator_Accuracy=80.2609, Generator_Loss=1.0884
# Epoch 291: Discriminator_Loss=1.1753, Discriminator_Accuracy=80.1740, Generator_Loss=1.0883
# Epoch 292: Discriminator_Loss=1.1738, Discriminator_Accuracy=80.0771, Generator_Loss=1.0882
# Epoch 293: Discriminator_Loss=1.1750, Discriminator_Accuracy=80.2120, Generator_Loss=1.0875
# Epoch 294: Discriminator_Loss=1.1737, Discriminator_Accuracy=80.2280, Generator_Loss=1.0896
# Epoch 295: Discriminator_Loss=1.1750, Discriminator_Accuracy=80.1720, Generator_Loss=1.0865
# Epoch 296: Discriminator_Loss=1.1747, Discriminator_Accuracy=80.2959, Generator_Loss=1.0878
# Epoch 297: Discriminator_Loss=1.1747, Discriminator_Accuracy=80.1950, Generator_Loss=1.0877
# Epoch 298: Discriminator_Loss=1.1741, Discriminator_Accuracy=80.2779, Generator_Loss=1.0879
# Epoch 299: Discriminator_Loss=1.1744, Discriminator_Accuracy=80.0901, Generator_Loss=1.0871
# Epoch 300: Discriminator_Loss=1.1743, Discriminator_Accuracy=80.2330, Generator_Loss=1.0884
# Epoch 301: Discriminator_Loss=1.1737, Discriminator_Accuracy=80.3199, Generator_Loss=1.0891
# Epoch 302: Discriminator_Loss=1.1736, Discriminator_Accuracy=80.2679, Generator_Loss=1.0883
# Epoch 303: Discriminator_Loss=1.1747, Discriminator_Accuracy=80.3139, Generator_Loss=1.0874
# Epoch 304: Discriminator_Loss=1.1739, Discriminator_Accuracy=80.3309, Generator_Loss=1.0880
# Epoch 305: Discriminator_Loss=1.1739, Discriminator_Accuracy=80.2869, Generator_Loss=1.0890
# Epoch 306: Discriminator_Loss=1.1733, Discriminator_Accuracy=80.1860, Generator_Loss=1.0886
# Epoch 307: Discriminator_Loss=1.1735, Discriminator_Accuracy=80.2580, Generator_Loss=1.0895
# Epoch 308: Discriminator_Loss=1.1745, Discriminator_Accuracy=80.2719, Generator_Loss=1.0883
# Epoch 309: Discriminator_Loss=1.1740, Discriminator_Accuracy=80.2600, Generator_Loss=1.0879
# Epoch 310: Discriminator_Loss=1.1739, Discriminator_Accuracy=80.3888, Generator_Loss=1.0874
# Epoch 311: Discriminator_Loss=1.1742, Discriminator_Accuracy=80.3589, Generator_Loss=1.0866
# Epoch 312: Discriminator_Loss=1.1734, Discriminator_Accuracy=80.4118, Generator_Loss=1.0878
# Epoch 313: Discriminator_Loss=1.1731, Discriminator_Accuracy=80.3798, Generator_Loss=1.0877
# Epoch 314: Discriminator_Loss=1.1739, Discriminator_Accuracy=80.3658, Generator_Loss=1.0872
# Epoch 315: Discriminator_Loss=1.1734, Discriminator_Accuracy=80.3019, Generator_Loss=1.0883
# Epoch 316: Discriminator_Loss=1.1740, Discriminator_Accuracy=80.1840, Generator_Loss=1.0882
# Epoch 317: Discriminator_Loss=1.1729, Discriminator_Accuracy=80.5027, Generator_Loss=1.0882
# Epoch 318: Discriminator_Loss=1.1733, Discriminator_Accuracy=80.3119, Generator_Loss=1.0853
# Epoch 319: Discriminator_Loss=1.1730, Discriminator_Accuracy=80.5077, Generator_Loss=1.0887
# Epoch 320: Discriminator_Loss=1.1742, Discriminator_Accuracy=80.4218, Generator_Loss=1.0868
# Epoch 321: Discriminator_Loss=1.1737, Discriminator_Accuracy=80.3788, Generator_Loss=1.0890
# Epoch 322: Discriminator_Loss=1.1726, Discriminator_Accuracy=80.6706, Generator_Loss=1.0879
# Epoch 323: Discriminator_Loss=1.1727, Discriminator_Accuracy=80.4408, Generator_Loss=1.0894
# Epoch 324: Discriminator_Loss=1.1734, Discriminator_Accuracy=80.4987, Generator_Loss=1.0880
# Epoch 325: Discriminator_Loss=1.1731, Discriminator_Accuracy=80.4887, Generator_Loss=1.0900
# Epoch 326: Discriminator_Loss=1.1741, Discriminator_Accuracy=80.3159, Generator_Loss=1.0865
# Epoch 327: Discriminator_Loss=1.1725, Discriminator_Accuracy=80.4747, Generator_Loss=1.0879
# Epoch 328: Discriminator_Loss=1.1723, Discriminator_Accuracy=80.6036, Generator_Loss=1.0870
# Epoch 329: Discriminator_Loss=1.1724, Discriminator_Accuracy=80.4797, Generator_Loss=1.0895
# Epoch 330: Discriminator_Loss=1.1729, Discriminator_Accuracy=80.5427, Generator_Loss=1.0858
# Epoch 331: Discriminator_Loss=1.1732, Discriminator_Accuracy=80.4268, Generator_Loss=1.0875
# Epoch 332: Discriminator_Loss=1.1723, Discriminator_Accuracy=80.6016, Generator_Loss=1.0890
# Epoch 333: Discriminator_Loss=1.1720, Discriminator_Accuracy=80.5327, Generator_Loss=1.0883
# Epoch 334: Discriminator_Loss=1.1711, Discriminator_Accuracy=80.5537, Generator_Loss=1.0887
# Epoch 335: Discriminator_Loss=1.1747, Discriminator_Accuracy=80.2989, Generator_Loss=1.0900
# Epoch 336: Discriminator_Loss=1.1736, Discriminator_Accuracy=80.3898, Generator_Loss=1.0891
# Epoch 337: Discriminator_Loss=1.1718, Discriminator_Accuracy=80.5986, Generator_Loss=1.0881
# Epoch 338: Discriminator_Loss=1.1720, Discriminator_Accuracy=80.5966, Generator_Loss=1.0885
# Epoch 339: Discriminator_Loss=1.1724, Discriminator_Accuracy=80.6486, Generator_Loss=1.0888
# Epoch 340: Discriminator_Loss=1.1728, Discriminator_Accuracy=80.4098, Generator_Loss=1.0874
# Epoch 341: Discriminator_Loss=1.1739, Discriminator_Accuracy=80.4648, Generator_Loss=1.0885
# Epoch 342: Discriminator_Loss=1.1731, Discriminator_Accuracy=80.5157, Generator_Loss=1.0887
# Epoch 343: Discriminator_Loss=1.1719, Discriminator_Accuracy=80.6036, Generator_Loss=1.0883
# Epoch 344: Discriminator_Loss=1.1716, Discriminator_Accuracy=80.6775, Generator_Loss=1.0886
# Epoch 345: Discriminator_Loss=1.1713, Discriminator_Accuracy=80.7894, Generator_Loss=1.0856
# Epoch 346: Discriminator_Loss=1.1721, Discriminator_Accuracy=80.5677, Generator_Loss=1.0860
# Epoch 347: Discriminator_Loss=1.1730, Discriminator_Accuracy=80.6386, Generator_Loss=1.0881
# Epoch 348: Discriminator_Loss=1.1717, Discriminator_Accuracy=80.6915, Generator_Loss=1.0875
# Epoch 349: Discriminator_Loss=1.1712, Discriminator_Accuracy=80.7005, Generator_Loss=1.0895
# Epoch 350: Discriminator_Loss=1.1710, Discriminator_Accuracy=80.7205, Generator_Loss=1.0874
# Epoch 351: Discriminator_Loss=1.1727, Discriminator_Accuracy=80.4867, Generator_Loss=1.0872
# Epoch 352: Discriminator_Loss=1.1730, Discriminator_Accuracy=80.6626, Generator_Loss=1.0887
# Epoch 353: Discriminator_Loss=1.1721, Discriminator_Accuracy=80.4847, Generator_Loss=1.0881
# Epoch 354: Discriminator_Loss=1.1715, Discriminator_Accuracy=80.6805, Generator_Loss=1.0897
# Epoch 355: Discriminator_Loss=1.1727, Discriminator_Accuracy=80.6256, Generator_Loss=1.0885
# Epoch 356: Discriminator_Loss=1.1720, Discriminator_Accuracy=80.6176, Generator_Loss=1.0887
# Epoch 357: Discriminator_Loss=1.1721, Discriminator_Accuracy=80.8064, Generator_Loss=1.0868
# Epoch 358: Discriminator_Loss=1.1720, Discriminator_Accuracy=80.6206, Generator_Loss=1.0887
# Epoch 359: Discriminator_Loss=1.1703, Discriminator_Accuracy=80.8454, Generator_Loss=1.0883
# Epoch 360: Discriminator_Loss=1.1728, Discriminator_Accuracy=80.5657, Generator_Loss=1.0885
# Epoch 361: Discriminator_Loss=1.1717, Discriminator_Accuracy=80.7035, Generator_Loss=1.0893
# Epoch 362: Discriminator_Loss=1.1712, Discriminator_Accuracy=80.7944, Generator_Loss=1.0873
# Epoch 363: Discriminator_Loss=1.1707, Discriminator_Accuracy=80.8044, Generator_Loss=1.0886
# Epoch 364: Discriminator_Loss=1.1726, Discriminator_Accuracy=80.7395, Generator_Loss=1.0867
# Epoch 365: Discriminator_Loss=1.1726, Discriminator_Accuracy=80.7495, Generator_Loss=1.0876
# Epoch 366: Discriminator_Loss=1.1724, Discriminator_Accuracy=80.7105, Generator_Loss=1.0893
# Epoch 367: Discriminator_Loss=1.1707, Discriminator_Accuracy=80.8284, Generator_Loss=1.0866
# Epoch 368: Discriminator_Loss=1.1716, Discriminator_Accuracy=80.7415, Generator_Loss=1.0864
# Epoch 369: Discriminator_Loss=1.1716, Discriminator_Accuracy=80.7834, Generator_Loss=1.0865
# Epoch 370: Discriminator_Loss=1.1714, Discriminator_Accuracy=80.8494, Generator_Loss=1.0875
# Epoch 371: Discriminator_Loss=1.1718, Discriminator_Accuracy=80.7615, Generator_Loss=1.0883
# Epoch 372: Discriminator_Loss=1.1712, Discriminator_Accuracy=80.8564, Generator_Loss=1.0877
# Epoch 373: Discriminator_Loss=1.1719, Discriminator_Accuracy=80.7305, Generator_Loss=1.0891
# Epoch 374: Discriminator_Loss=1.1720, Discriminator_Accuracy=80.7635, Generator_Loss=1.0862
# Epoch 375: Discriminator_Loss=1.1713, Discriminator_Accuracy=80.8124, Generator_Loss=1.0870
# Epoch 376: Discriminator_Loss=1.1720, Discriminator_Accuracy=80.8464, Generator_Loss=1.0871
# Epoch 377: Discriminator_Loss=1.1717, Discriminator_Accuracy=80.9323, Generator_Loss=1.0850
# Epoch 378: Discriminator_Loss=1.1706, Discriminator_Accuracy=80.9563, Generator_Loss=1.0863
# Epoch 379: Discriminator_Loss=1.1710, Discriminator_Accuracy=80.9843, Generator_Loss=1.0858
# Epoch 380: Discriminator_Loss=1.1714, Discriminator_Accuracy=80.9343, Generator_Loss=1.0869
# Epoch 381: Discriminator_Loss=1.1726, Discriminator_Accuracy=80.8644, Generator_Loss=1.0876
# Epoch 382: Discriminator_Loss=1.1714, Discriminator_Accuracy=80.8544, Generator_Loss=1.0862
# Epoch 383: Discriminator_Loss=1.1712, Discriminator_Accuracy=80.9433, Generator_Loss=1.0866
# Epoch 384: Discriminator_Loss=1.1712, Discriminator_Accuracy=80.9313, Generator_Loss=1.0863
# Epoch 385: Discriminator_Loss=1.1707, Discriminator_Accuracy=80.8913, Generator_Loss=1.0863
# Epoch 386: Discriminator_Loss=1.1719, Discriminator_Accuracy=80.8893, Generator_Loss=1.0860
# Epoch 387: Discriminator_Loss=1.1710, Discriminator_Accuracy=80.7585, Generator_Loss=1.0882
# Epoch 388: Discriminator_Loss=1.1706, Discriminator_Accuracy=80.9823, Generator_Loss=1.0867
# Epoch 389: Discriminator_Loss=1.1715, Discriminator_Accuracy=80.9603, Generator_Loss=1.0867
# Epoch 390: Discriminator_Loss=1.1713, Discriminator_Accuracy=80.9573, Generator_Loss=1.0875
# Epoch 391: Discriminator_Loss=1.1720, Discriminator_Accuracy=80.8744, Generator_Loss=1.0862
# Epoch 392: Discriminator_Loss=1.1710, Discriminator_Accuracy=80.9593, Generator_Loss=1.0861
# Epoch 393: Discriminator_Loss=1.1712, Discriminator_Accuracy=81.0432, Generator_Loss=1.0861
# Epoch 394: Discriminator_Loss=1.1707, Discriminator_Accuracy=81.0652, Generator_Loss=1.0879
# Epoch 395: Discriminator_Loss=1.1710, Discriminator_Accuracy=81.1451, Generator_Loss=1.0874
# Epoch 396: Discriminator_Loss=1.1703, Discriminator_Accuracy=81.0712, Generator_Loss=1.0856
# Epoch 397: Discriminator_Loss=1.1703, Discriminator_Accuracy=81.1521, Generator_Loss=1.0855
# Epoch 398: Discriminator_Loss=1.1699, Discriminator_Accuracy=81.1801, Generator_Loss=1.0861
# Epoch 399: Discriminator_Loss=1.1708, Discriminator_Accuracy=81.0162, Generator_Loss=1.0850
# Epoch 400: Discriminator_Loss=1.1705, Discriminator_Accuracy=81.1351, Generator_Loss=1.0862
# Epoch 401: Discriminator_Loss=1.1704, Discriminator_Accuracy=80.9593, Generator_Loss=1.0873
# Epoch 402: Discriminator_Loss=1.1704, Discriminator_Accuracy=81.1201, Generator_Loss=1.0864
# Epoch 403: Discriminator_Loss=1.1706, Discriminator_Accuracy=81.0951, Generator_Loss=1.0871
# Epoch 404: Discriminator_Loss=1.1699, Discriminator_Accuracy=81.2370, Generator_Loss=1.0860
# Epoch 405: Discriminator_Loss=1.1699, Discriminator_Accuracy=81.0752, Generator_Loss=1.0875
# Epoch 406: Discriminator_Loss=1.1690, Discriminator_Accuracy=81.1051, Generator_Loss=1.0870
# Epoch 407: Discriminator_Loss=1.1701, Discriminator_Accuracy=81.1611, Generator_Loss=1.0866
# Epoch 408: Discriminator_Loss=1.1694, Discriminator_Accuracy=81.1131, Generator_Loss=1.0888
# Epoch 409: Discriminator_Loss=1.1692, Discriminator_Accuracy=81.2540, Generator_Loss=1.0868
# Epoch 410: Discriminator_Loss=1.1690, Discriminator_Accuracy=81.2550, Generator_Loss=1.0855
# Epoch 411: Discriminator_Loss=1.1707, Discriminator_Accuracy=81.1401, Generator_Loss=1.0871
# Epoch 412: Discriminator_Loss=1.1693, Discriminator_Accuracy=81.2310, Generator_Loss=1.0868
# Epoch 413: Discriminator_Loss=1.1697, Discriminator_Accuracy=81.1471, Generator_Loss=1.0861
# Epoch 414: Discriminator_Loss=1.1701, Discriminator_Accuracy=81.1201, Generator_Loss=1.0849
# Epoch 415: Discriminator_Loss=1.1711, Discriminator_Accuracy=81.0162, Generator_Loss=1.0870
# Epoch 416: Discriminator_Loss=1.1690, Discriminator_Accuracy=81.2170, Generator_Loss=1.0872
# Epoch 417: Discriminator_Loss=1.1704, Discriminator_Accuracy=81.1821, Generator_Loss=1.0876
# Epoch 418: Discriminator_Loss=1.1710, Discriminator_Accuracy=81.1711, Generator_Loss=1.0853
# Epoch 419: Discriminator_Loss=1.1710, Discriminator_Accuracy=81.2100, Generator_Loss=1.0851
# Epoch 420: Discriminator_Loss=1.1707, Discriminator_Accuracy=81.1711, Generator_Loss=1.0857
# Epoch 421: Discriminator_Loss=1.1689, Discriminator_Accuracy=81.2880, Generator_Loss=1.0867
# Epoch 422: Discriminator_Loss=1.1693, Discriminator_Accuracy=81.1971, Generator_Loss=1.0863
# Epoch 423: Discriminator_Loss=1.1691, Discriminator_Accuracy=81.3020, Generator_Loss=1.0862
# Epoch 424: Discriminator_Loss=1.1699, Discriminator_Accuracy=81.3099, Generator_Loss=1.0854
# Epoch 425: Discriminator_Loss=1.1685, Discriminator_Accuracy=81.3869, Generator_Loss=1.0864
# Epoch 426: Discriminator_Loss=1.1691, Discriminator_Accuracy=81.2980, Generator_Loss=1.0851
# Epoch 427: Discriminator_Loss=1.1696, Discriminator_Accuracy=81.2270, Generator_Loss=1.0875
# Epoch 428: Discriminator_Loss=1.1689, Discriminator_Accuracy=81.3499, Generator_Loss=1.0880
# Epoch 429: Discriminator_Loss=1.1695, Discriminator_Accuracy=81.1481, Generator_Loss=1.0866
# Epoch 430: Discriminator_Loss=1.1688, Discriminator_Accuracy=81.3069, Generator_Loss=1.0842
# Epoch 431: Discriminator_Loss=1.1699, Discriminator_Accuracy=81.2670, Generator_Loss=1.0857
# Epoch 432: Discriminator_Loss=1.1697, Discriminator_Accuracy=81.1341, Generator_Loss=1.0861
# Epoch 433: Discriminator_Loss=1.1684, Discriminator_Accuracy=81.2820, Generator_Loss=1.0879
# Epoch 434: Discriminator_Loss=1.1696, Discriminator_Accuracy=81.3789, Generator_Loss=1.0862
# Epoch 435: Discriminator_Loss=1.1693, Discriminator_Accuracy=81.2900, Generator_Loss=1.0867
# Epoch 436: Discriminator_Loss=1.1682, Discriminator_Accuracy=81.3759, Generator_Loss=1.0843
# Epoch 437: Discriminator_Loss=1.1691, Discriminator_Accuracy=81.1990, Generator_Loss=1.0855
# Epoch 438: Discriminator_Loss=1.1691, Discriminator_Accuracy=81.2370, Generator_Loss=1.0901
# Epoch 439: Discriminator_Loss=1.1694, Discriminator_Accuracy=81.3559, Generator_Loss=1.0872
# Epoch 440: Discriminator_Loss=1.1697, Discriminator_Accuracy=81.3149, Generator_Loss=1.0858
# Epoch 441: Discriminator_Loss=1.1697, Discriminator_Accuracy=81.3119, Generator_Loss=1.0866
# Epoch 442: Discriminator_Loss=1.1691, Discriminator_Accuracy=81.3259, Generator_Loss=1.0859
# Epoch 443: Discriminator_Loss=1.1695, Discriminator_Accuracy=81.4168, Generator_Loss=1.0835
# Epoch 444: Discriminator_Loss=1.1688, Discriminator_Accuracy=81.4188, Generator_Loss=1.0862
# Epoch 445: Discriminator_Loss=1.1695, Discriminator_Accuracy=81.2730, Generator_Loss=1.0867
# Epoch 446: Discriminator_Loss=1.1687, Discriminator_Accuracy=81.4508, Generator_Loss=1.0869
# Epoch 447: Discriminator_Loss=1.1683, Discriminator_Accuracy=81.4188, Generator_Loss=1.0868
# Epoch 448: Discriminator_Loss=1.1690, Discriminator_Accuracy=81.3869, Generator_Loss=1.0868
# Epoch 449: Discriminator_Loss=1.1688, Discriminator_Accuracy=81.5088, Generator_Loss=1.0866
# Epoch 450: Discriminator_Loss=1.1677, Discriminator_Accuracy=81.4108, Generator_Loss=1.0873
# Epoch 451: Discriminator_Loss=1.1701, Discriminator_Accuracy=81.3429, Generator_Loss=1.0856
# Epoch 452: Discriminator_Loss=1.1695, Discriminator_Accuracy=81.1901, Generator_Loss=1.0858
# Epoch 453: Discriminator_Loss=1.1682, Discriminator_Accuracy=81.4668, Generator_Loss=1.0867
# Epoch 454: Discriminator_Loss=1.1699, Discriminator_Accuracy=81.4068, Generator_Loss=1.0855
# Epoch 455: Discriminator_Loss=1.1673, Discriminator_Accuracy=81.3509, Generator_Loss=1.0870
# Epoch 456: Discriminator_Loss=1.1693, Discriminator_Accuracy=81.2990, Generator_Loss=1.0868
# Epoch 457: Discriminator_Loss=1.1687, Discriminator_Accuracy=81.4608, Generator_Loss=1.0850
# Epoch 458: Discriminator_Loss=1.1680, Discriminator_Accuracy=81.3989, Generator_Loss=1.0874
# Epoch 459: Discriminator_Loss=1.1688, Discriminator_Accuracy=81.4208, Generator_Loss=1.0856
# Epoch 460: Discriminator_Loss=1.1680, Discriminator_Accuracy=81.4448, Generator_Loss=1.0857
# Epoch 461: Discriminator_Loss=1.1697, Discriminator_Accuracy=81.3029, Generator_Loss=1.0845
# Epoch 462: Discriminator_Loss=1.1694, Discriminator_Accuracy=81.4538, Generator_Loss=1.0865
# Epoch 463: Discriminator_Loss=1.1687, Discriminator_Accuracy=81.3209, Generator_Loss=1.0867
# Epoch 464: Discriminator_Loss=1.1689, Discriminator_Accuracy=81.4748, Generator_Loss=1.0858
# Epoch 465: Discriminator_Loss=1.1683, Discriminator_Accuracy=81.4838, Generator_Loss=1.0855
# Epoch 466: Discriminator_Loss=1.1688, Discriminator_Accuracy=81.4738, Generator_Loss=1.0851
# Epoch 467: Discriminator_Loss=1.1691, Discriminator_Accuracy=81.4118, Generator_Loss=1.0851
# Epoch 468: Discriminator_Loss=1.1678, Discriminator_Accuracy=81.4818, Generator_Loss=1.0864
# Epoch 469: Discriminator_Loss=1.1683, Discriminator_Accuracy=81.5887, Generator_Loss=1.0855
# Epoch 470: Discriminator_Loss=1.1674, Discriminator_Accuracy=81.5427, Generator_Loss=1.0872
# Epoch 471: Discriminator_Loss=1.1676, Discriminator_Accuracy=81.5387, Generator_Loss=1.0867
# Epoch 472: Discriminator_Loss=1.1681, Discriminator_Accuracy=81.5927, Generator_Loss=1.0867
# Epoch 473: Discriminator_Loss=1.1683, Discriminator_Accuracy=81.5048, Generator_Loss=1.0882
# Epoch 474: Discriminator_Loss=1.1676, Discriminator_Accuracy=81.5617, Generator_Loss=1.0859
# Epoch 475: Discriminator_Loss=1.1669, Discriminator_Accuracy=81.4788, Generator_Loss=1.0898
# Epoch 476: Discriminator_Loss=1.1694, Discriminator_Accuracy=81.5127, Generator_Loss=1.0848
# Epoch 477: Discriminator_Loss=1.1684, Discriminator_Accuracy=81.5088, Generator_Loss=1.0861
# Epoch 478: Discriminator_Loss=1.1685, Discriminator_Accuracy=81.5048, Generator_Loss=1.0853
# Epoch 479: Discriminator_Loss=1.1681, Discriminator_Accuracy=81.5197, Generator_Loss=1.0870
# Epoch 480: Discriminator_Loss=1.1693, Discriminator_Accuracy=81.4228, Generator_Loss=1.0862
# Epoch 481: Discriminator_Loss=1.1685, Discriminator_Accuracy=81.4708, Generator_Loss=1.0853
# Epoch 482: Discriminator_Loss=1.1686, Discriminator_Accuracy=81.6156, Generator_Loss=1.0840
# Epoch 483: Discriminator_Loss=1.1683, Discriminator_Accuracy=81.5147, Generator_Loss=1.0837
# Epoch 484: Discriminator_Loss=1.1689, Discriminator_Accuracy=81.4768, Generator_Loss=1.0860
# Epoch 485: Discriminator_Loss=1.1677, Discriminator_Accuracy=81.5737, Generator_Loss=1.0873
# Epoch 486: Discriminator_Loss=1.1689, Discriminator_Accuracy=81.5807, Generator_Loss=1.0840
# Epoch 487: Discriminator_Loss=1.1684, Discriminator_Accuracy=81.4928, Generator_Loss=1.0867
# Epoch 488: Discriminator_Loss=1.1685, Discriminator_Accuracy=81.6047, Generator_Loss=1.0867
# Epoch 489: Discriminator_Loss=1.1694, Discriminator_Accuracy=81.5667, Generator_Loss=1.0854
# Epoch 490: Discriminator_Loss=1.1693, Discriminator_Accuracy=81.5187, Generator_Loss=1.0846
# Epoch 491: Discriminator_Loss=1.1679, Discriminator_Accuracy=81.6306, Generator_Loss=1.0858
# Epoch 492: Discriminator_Loss=1.1681, Discriminator_Accuracy=81.6027, Generator_Loss=1.0840
# Epoch 493: Discriminator_Loss=1.1681, Discriminator_Accuracy=81.7016, Generator_Loss=1.0866
# Epoch 494: Discriminator_Loss=1.1692, Discriminator_Accuracy=81.4988, Generator_Loss=1.0852
# Epoch 495: Discriminator_Loss=1.1688, Discriminator_Accuracy=81.5197, Generator_Loss=1.0851
# Epoch 496: Discriminator_Loss=1.1689, Discriminator_Accuracy=81.4568, Generator_Loss=1.0847
# Epoch 497: Discriminator_Loss=1.1679, Discriminator_Accuracy=81.6896, Generator_Loss=1.0856
# Epoch 498: Discriminator_Loss=1.1676, Discriminator_Accuracy=81.7515, Generator_Loss=1.0841
# Epoch 499: Discriminator_Loss=1.1672, Discriminator_Accuracy=81.7985, Generator_Loss=1.0832
# Epoch 500: Discriminator_Loss=1.1677, Discriminator_Accuracy=81.4968, Generator_Loss=1.0849
# Epoch 501: Discriminator_Loss=1.1683, Discriminator_Accuracy=81.6536, Generator_Loss=1.0855
# Epoch 502: Discriminator_Loss=1.1678, Discriminator_Accuracy=81.7385, Generator_Loss=1.0849
# Epoch 503: Discriminator_Loss=1.1669, Discriminator_Accuracy=81.7445, Generator_Loss=1.0842
# Epoch 504: Discriminator_Loss=1.1673, Discriminator_Accuracy=81.7915, Generator_Loss=1.0853
# Epoch 505: Discriminator_Loss=1.1674, Discriminator_Accuracy=81.7775, Generator_Loss=1.0865
# Epoch 506: Discriminator_Loss=1.1680, Discriminator_Accuracy=81.6596, Generator_Loss=1.0838
# Epoch 507: Discriminator_Loss=1.1677, Discriminator_Accuracy=81.6516, Generator_Loss=1.0843
# Epoch 508: Discriminator_Loss=1.1677, Discriminator_Accuracy=81.7525, Generator_Loss=1.0845
# Epoch 509: Discriminator_Loss=1.1675, Discriminator_Accuracy=81.8065, Generator_Loss=1.0837
# Epoch 510: Discriminator_Loss=1.1678, Discriminator_Accuracy=81.7515, Generator_Loss=1.0833
# Epoch 511: Discriminator_Loss=1.1668, Discriminator_Accuracy=81.8864, Generator_Loss=1.0856
# Epoch 512: Discriminator_Loss=1.1671, Discriminator_Accuracy=81.7765, Generator_Loss=1.0834
# Epoch 513: Discriminator_Loss=1.1670, Discriminator_Accuracy=81.7575, Generator_Loss=1.0857
# Epoch 514: Discriminator_Loss=1.1674, Discriminator_Accuracy=81.9094, Generator_Loss=1.0845
# Epoch 515: Discriminator_Loss=1.1670, Discriminator_Accuracy=81.7855, Generator_Loss=1.0856
# Epoch 516: Discriminator_Loss=1.1668, Discriminator_Accuracy=81.8964, Generator_Loss=1.0865
# Epoch 517: Discriminator_Loss=1.1668, Discriminator_Accuracy=81.9493, Generator_Loss=1.0843
# Epoch 518: Discriminator_Loss=1.1671, Discriminator_Accuracy=81.7225, Generator_Loss=1.0859
# Epoch 519: Discriminator_Loss=1.1677, Discriminator_Accuracy=81.7595, Generator_Loss=1.0856
# Epoch 520: Discriminator_Loss=1.1661, Discriminator_Accuracy=81.9114, Generator_Loss=1.0841
# Epoch 521: Discriminator_Loss=1.1666, Discriminator_Accuracy=81.7655, Generator_Loss=1.0856
# Epoch 522: Discriminator_Loss=1.1672, Discriminator_Accuracy=81.8464, Generator_Loss=1.0846
# Epoch 523: Discriminator_Loss=1.1674, Discriminator_Accuracy=81.8944, Generator_Loss=1.0833
# Epoch 524: Discriminator_Loss=1.1677, Discriminator_Accuracy=81.9254, Generator_Loss=1.0827
# Epoch 525: Discriminator_Loss=1.1671, Discriminator_Accuracy=81.8045, Generator_Loss=1.0855
# Epoch 526: Discriminator_Loss=1.1666, Discriminator_Accuracy=81.8844, Generator_Loss=1.0842
# Epoch 527: Discriminator_Loss=1.1667, Discriminator_Accuracy=81.8085, Generator_Loss=1.0828
# Epoch 528: Discriminator_Loss=1.1659, Discriminator_Accuracy=81.9104, Generator_Loss=1.0845
# Epoch 529: Discriminator_Loss=1.1651, Discriminator_Accuracy=81.9903, Generator_Loss=1.0845
# Epoch 530: Discriminator_Loss=1.1671, Discriminator_Accuracy=81.8484, Generator_Loss=1.0819
# Epoch 531: Discriminator_Loss=1.1673, Discriminator_Accuracy=81.8704, Generator_Loss=1.0832
# Epoch 532: Discriminator_Loss=1.1672, Discriminator_Accuracy=81.8784, Generator_Loss=1.0833
# Epoch 533: Discriminator_Loss=1.1673, Discriminator_Accuracy=81.8264, Generator_Loss=1.0838
# Epoch 534: Discriminator_Loss=1.1668, Discriminator_Accuracy=81.8974, Generator_Loss=1.0846
# Epoch 535: Discriminator_Loss=1.1674, Discriminator_Accuracy=81.7925, Generator_Loss=1.0840
# Epoch 536: Discriminator_Loss=1.1652, Discriminator_Accuracy=82.0163, Generator_Loss=1.0852
# Epoch 537: Discriminator_Loss=1.1658, Discriminator_Accuracy=82.0402, Generator_Loss=1.0824
# Epoch 538: Discriminator_Loss=1.1667, Discriminator_Accuracy=81.8844, Generator_Loss=1.0837
# Epoch 539: Discriminator_Loss=1.1667, Discriminator_Accuracy=81.9943, Generator_Loss=1.0844
# Epoch 540: Discriminator_Loss=1.1674, Discriminator_Accuracy=81.9044, Generator_Loss=1.0847
# Epoch 541: Discriminator_Loss=1.1670, Discriminator_Accuracy=81.8804, Generator_Loss=1.0852
# Epoch 542: Discriminator_Loss=1.1662, Discriminator_Accuracy=82.0582, Generator_Loss=1.0849
# Epoch 543: Discriminator_Loss=1.1665, Discriminator_Accuracy=82.0842, Generator_Loss=1.0836
# Epoch 544: Discriminator_Loss=1.1668, Discriminator_Accuracy=81.8514, Generator_Loss=1.0830
# Epoch 545: Discriminator_Loss=1.1655, Discriminator_Accuracy=82.1511, Generator_Loss=1.0826
# Epoch 546: Discriminator_Loss=1.1662, Discriminator_Accuracy=82.0892, Generator_Loss=1.0843
# Epoch 547: Discriminator_Loss=1.1658, Discriminator_Accuracy=82.1511, Generator_Loss=1.0834
# Epoch 548: Discriminator_Loss=1.1665, Discriminator_Accuracy=81.9713, Generator_Loss=1.0839
# Epoch 549: Discriminator_Loss=1.1662, Discriminator_Accuracy=82.0692, Generator_Loss=1.0833
# Epoch 550: Discriminator_Loss=1.1662, Discriminator_Accuracy=82.0043, Generator_Loss=1.0833
# Epoch 551: Discriminator_Loss=1.1657, Discriminator_Accuracy=82.0762, Generator_Loss=1.0842
# Epoch 552: Discriminator_Loss=1.1661, Discriminator_Accuracy=82.0732, Generator_Loss=1.0835
# Epoch 553: Discriminator_Loss=1.1670, Discriminator_Accuracy=81.8844, Generator_Loss=1.0854
# Epoch 554: Discriminator_Loss=1.1667, Discriminator_Accuracy=81.9144, Generator_Loss=1.0841
# Epoch 555: Discriminator_Loss=1.1662, Discriminator_Accuracy=81.9763, Generator_Loss=1.0850
# Epoch 556: Discriminator_Loss=1.1665, Discriminator_Accuracy=82.0103, Generator_Loss=1.0842
# Epoch 557: Discriminator_Loss=1.1655, Discriminator_Accuracy=82.1242, Generator_Loss=1.0841
# Epoch 558: Discriminator_Loss=1.1669, Discriminator_Accuracy=81.9913, Generator_Loss=1.0839
# Epoch 559: Discriminator_Loss=1.1656, Discriminator_Accuracy=82.1112, Generator_Loss=1.0833
# Epoch 560: Discriminator_Loss=1.1658, Discriminator_Accuracy=82.0492, Generator_Loss=1.0841
# Epoch 561: Discriminator_Loss=1.1654, Discriminator_Accuracy=82.0492, Generator_Loss=1.0847
# Epoch 562: Discriminator_Loss=1.1671, Discriminator_Accuracy=81.8704, Generator_Loss=1.0829
# Epoch 563: Discriminator_Loss=1.1668, Discriminator_Accuracy=82.0422, Generator_Loss=1.0833
# Epoch 564: Discriminator_Loss=1.1654, Discriminator_Accuracy=82.1232, Generator_Loss=1.0842
# Epoch 565: Discriminator_Loss=1.1665, Discriminator_Accuracy=82.0422, Generator_Loss=1.0827
# Epoch 566: Discriminator_Loss=1.1670, Discriminator_Accuracy=82.0013, Generator_Loss=1.0832
# Epoch 567: Discriminator_Loss=1.1657, Discriminator_Accuracy=82.1831, Generator_Loss=1.0825
# Epoch 568: Discriminator_Loss=1.1665, Discriminator_Accuracy=81.9753, Generator_Loss=1.0855
# Epoch 569: Discriminator_Loss=1.1662, Discriminator_Accuracy=81.9583, Generator_Loss=1.0844
# Epoch 570: Discriminator_Loss=1.1657, Discriminator_Accuracy=82.0273, Generator_Loss=1.0839
# Epoch 571: Discriminator_Loss=1.1658, Discriminator_Accuracy=82.0972, Generator_Loss=1.0847
# Epoch 572: Discriminator_Loss=1.1666, Discriminator_Accuracy=82.0892, Generator_Loss=1.0829
# Epoch 573: Discriminator_Loss=1.1653, Discriminator_Accuracy=82.1162, Generator_Loss=1.0850
# Epoch 574: Discriminator_Loss=1.1671, Discriminator_Accuracy=82.0672, Generator_Loss=1.0824
# Epoch 575: Discriminator_Loss=1.1659, Discriminator_Accuracy=82.0482, Generator_Loss=1.0828
# Epoch 576: Discriminator_Loss=1.1665, Discriminator_Accuracy=82.0402, Generator_Loss=1.0840
# Epoch 577: Discriminator_Loss=1.1664, Discriminator_Accuracy=82.0203, Generator_Loss=1.0836
# Epoch 578: Discriminator_Loss=1.1670, Discriminator_Accuracy=82.1122, Generator_Loss=1.0807
# Epoch 579: Discriminator_Loss=1.1658, Discriminator_Accuracy=82.1601, Generator_Loss=1.0839
# Epoch 580: Discriminator_Loss=1.1656, Discriminator_Accuracy=82.2400, Generator_Loss=1.0824
# Epoch 581: Discriminator_Loss=1.1653, Discriminator_Accuracy=82.2281, Generator_Loss=1.0842
# Epoch 582: Discriminator_Loss=1.1657, Discriminator_Accuracy=82.1621, Generator_Loss=1.0831
# Epoch 583: Discriminator_Loss=1.1661, Discriminator_Accuracy=82.0792, Generator_Loss=1.0828
# Epoch 584: Discriminator_Loss=1.1660, Discriminator_Accuracy=82.1302, Generator_Loss=1.0827
# Epoch 585: Discriminator_Loss=1.1661, Discriminator_Accuracy=82.1292, Generator_Loss=1.0834
# Epoch 586: Discriminator_Loss=1.1662, Discriminator_Accuracy=82.0312, Generator_Loss=1.0837
# Epoch 587: Discriminator_Loss=1.1659, Discriminator_Accuracy=82.2181, Generator_Loss=1.0838
# Epoch 588: Discriminator_Loss=1.1656, Discriminator_Accuracy=82.1471, Generator_Loss=1.0825
# Epoch 589: Discriminator_Loss=1.1667, Discriminator_Accuracy=82.0852, Generator_Loss=1.0833
# Epoch 590: Discriminator_Loss=1.1645, Discriminator_Accuracy=82.3250, Generator_Loss=1.0835
# Epoch 591: Discriminator_Loss=1.1653, Discriminator_Accuracy=82.3130, Generator_Loss=1.0831
# Epoch 592: Discriminator_Loss=1.1654, Discriminator_Accuracy=82.2381, Generator_Loss=1.0818
# Epoch 593: Discriminator_Loss=1.1646, Discriminator_Accuracy=82.2460, Generator_Loss=1.0828
# Epoch 594: Discriminator_Loss=1.1650, Discriminator_Accuracy=82.2780, Generator_Loss=1.0834
# Epoch 595: Discriminator_Loss=1.1651, Discriminator_Accuracy=82.2740, Generator_Loss=1.0831
# Epoch 596: Discriminator_Loss=1.1652, Discriminator_Accuracy=82.2820, Generator_Loss=1.0831
# Epoch 597: Discriminator_Loss=1.1637, Discriminator_Accuracy=82.4029, Generator_Loss=1.0830
# Epoch 598: Discriminator_Loss=1.1647, Discriminator_Accuracy=82.3140, Generator_Loss=1.0843
# Epoch 599: Discriminator_Loss=1.1655, Discriminator_Accuracy=82.1781, Generator_Loss=1.0842
# Epoch 600: Discriminator_Loss=1.1656, Discriminator_Accuracy=82.2780, Generator_Loss=1.0836
