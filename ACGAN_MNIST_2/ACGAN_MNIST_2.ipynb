# %%
#Import librerie di cui necessitiamo
import argparse
import os
import numpy as np
import math

import torchvision.transforms as transforms
from torchvision.utils import save_image

from torch.utils.data import DataLoader
from torchvision import datasets
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F
import torch

# %%
"""Creiamo una directory in cui andremo a salvare tutte le immagini che man mano
verranno generate in fase di training del modello per valutare quanto il modello
sta funzionando bene"""
os.makedirs("results_images", exist_ok=True)

# %%
"""Sfruttando la libreria argparse creiamo una sorta di namespace contenente
tutte le variabili che ci serviranno da ora in avanti"""
parser = argparse.ArgumentParser()
parser.add_argument('-f')
parser.add_argument("--n_epochs", type=int, default=200, help="number of epochs of training")
parser.add_argument("--batch_size", type=int, default=64, help="size of the batches")
parser.add_argument("--lr", type=float, default=0.0002, help="adam: learning rate")
parser.add_argument("--b1", type=float, default=0.5, help="adam: decay of first order momentum of gradient")
parser.add_argument("--b2", type=float, default=0.999, help="adam: decay of first order momentum of gradient")
parser.add_argument("--n_cpu", type=int, default=4, help="number of cpu threads to use during batch generation")
parser.add_argument("--latent_dim", type=int, default=100, help="dimensionality of the latent space")
parser.add_argument("--n_classes", type=int, default=10, help="number of classes for dataset")
parser.add_argument("--img_size", type=int, default=32, help="size of each image dimension")
parser.add_argument("--channels", type=int, default=1, help="number of image channels")
parser.add_argument("--sample_interval", type=int, default=10, help="interval between image sampling")
opt = parser.parse_args()
print(opt)
# Out:
# Namespace(b1=0.5, b2=0.999, batch_size=64, channels=1, f='/root/.local/share/jupyter/runtime/kernel-5bd6d2cc-9a49-4dfc-b61a-22cce2c22c85.json', img_size=32, latent_dim=100, lr=0.0002, n_classes=10, n_cpu=4, n_epochs=200, sample_interval=10)

# %%
"""Al reference cuda assegniamo True se la GPU è disponibile, altrimenti gli
assegniamo False"""
cuda = True if torch.cuda.is_available() else False

# %%
"""Tale funzione come parametro riceve un modulo presente all'interno del
generatore o del discriminatore e se il modulo è di tipo Conv o sottotipo di
Conv (ad esempio Conv2d) allora vengono inizializzati i pesi di tale modulo, se
il modulo è di tipo BatchNorm2d allora vengono inizializzati i pesi e i bias di
tale modulo"""
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("BatchNorm2d") != -1:
        torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant_(m.bias.data, 0.0)

# %%
"""Modello del generatore"""
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.label_emb = nn.Embedding(opt.n_classes, opt.latent_dim)

        self.fcl = nn.Linear(opt.latent_dim, 64 * (opt.img_size // 4) * (opt.img_size // 4))

        self.conv_layers = nn.Sequential(
            nn.BatchNorm2d(64),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),

            nn.BatchNorm2d(64, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(64, 32, kernel_size=3, padding=1),

            nn.BatchNorm2d(32, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(32, opt.channels, kernel_size=3, padding=1),

            nn.Tanh()
        )

    def forward(self, noise, labels):
        gen_input = torch.mul(self.label_emb(labels), noise)
        fcl_out = self.fcl(gen_input)
        img = fcl_out.view(fcl_out.size(0), 64, opt.img_size // 4, opt.img_size // 4)
        imgs = self.conv_layers(img)
        return imgs

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        def block(in_channels, out_channels, bn=True):
            layers = nn.ModuleList([nn.Conv2d(in_channels, out_channels, 3, 2, 1),
                                    nn.LeakyReLU(0.2, inplace=True),
                                    nn.Dropout2d(0.2)])
            if bn:
                layers.append(nn.BatchNorm2d(out_channels, 0.8))
            return layers

        self.conv_layers = nn.Sequential(
            *block(opt.channels, 16, bn=False),
            *block(16, 32),
            *block(32, 64)
        )

        self.adv_layer = nn.Sequential(
            nn.Linear(64 * 4 * 4, 1),
            nn.Sigmoid()
        )


        self.aux_layer = nn.Sequential(
            nn.Linear(64 * 4 * 4, opt.n_classes),
            nn.Softmax()
        )


    def forward(self, img):
        img = self.conv_layers(img)
        fcl_in = img.view(img.size(0), -1)
        validity = self.adv_layer(fcl_in)
        label = self.aux_layer(fcl_in)
        return validity, label

# %%
#Definiamo le Loss Function che ci serviranno"""
adversarial_loss = torch.nn.BCELoss()
auxiliary_loss = torch.nn.CrossEntropyLoss()

# %%
# Initialize generator and discriminator
generator = Generator()
discriminator = Discriminator()

# %%
"""Se la GPU è disponibile spostiamo i modelli e le Loss all'interno della GPU"""
if cuda:
    generator.cuda()
    discriminator.cuda()
    adversarial_loss.cuda()
    auxiliary_loss.cuda()

# %%
#Inizializziamo i parametri dei moduli presenti all'interno del generatore e del discriminatore
"""Supponiamo di considerare la funzione apply invocata su generator. Tale funzione
in maniera iterativa prende ogni singolo modulo presente all'interno di generator
e lo passa come parametro della funzione weights_init_normal"""
generator.apply(weights_init_normal)
discriminator.apply(weights_init_normal)
# Out:
# Discriminator(
#   (conv_layers): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Dropout2d(p=0.2, inplace=False)
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Dropout2d(p=0.2, inplace=False)
#     (6): BatchNorm2d(32, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (8): LeakyReLU(negative_slope=0.2, inplace=True)
#     (9): Dropout2d(p=0.2, inplace=False)
#     (10): BatchNorm2d(64, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (adv_layer): Sequential(
#     (0): Linear(in_features=1024, out_features=1, bias=True)
#     (1): Sigmoid()
#   )
#   (aux_layer): Sequential(
#     (0): Linear(in_features=1024, out_features=10, bias=True)
#     (1): Softmax(dim=None)
#   )
# )

# %%
# Configure data loader
os.makedirs("../../data/mnist", exist_ok=True)
dataloader = torch.utils.data.DataLoader(
    datasets.MNIST(
        "../../data/mnist",
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.Resize(opt.img_size), transforms.ToTensor(), transforms.Normalize([0.5], [0.5])]
        ),
    ),
    batch_size=opt.batch_size,
    shuffle=True,
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting ../../data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting ../../data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting ../../data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting ../../data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# Processing...
# Done!
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:502: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:143.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
#Creiamo gli ottimizzatori
optimizer_G = torch.optim.Adam(generator.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2))

# %%
FloatTensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if cuda else torch.LongTensor

# %%
def sample_image(n_row, epoch):
    """Saves a grid of generated digits ranging from 0 to n_classes"""
    # Sample noise
    """Per generare z, ossia il minibatch contenente rumore casuale da mandare in ingresso
    al generatore abbiamo creato un Tensor 2-D avente un numero di righe pari a
    n_row**2 e un numero di colonne pari a 100. Dopodiché, dal momento che vogliamo
    che questo Tensor contenga sempre gli stessi valori anche se la funzione sample_image
    viene chiamata più volte abbiamo deciso di wrappare tale Tensor all'interno di Variable.
    Così facendo, anche se la funzione sample_image viene chiamata più volte, il valore di z
    rimane invariato"""
    z = Variable(FloatTensor(np.random.normal(0, 1, (n_row ** 2, opt.latent_dim))))
    # Get labels ranging from 0 to n_classes for n rows
    labels = np.array([num for _ in range(n_row) for num in range(n_row)])
    labels = Variable(LongTensor(labels))
    """Per generare labels, ossia il minibatch contenente i target da mandare in ingresso
    al generatore abbiamo creato un Tensor 1-D avente un numero di elementi pari a 100
    (numero di righe di z), dove l'elemento di indice 0 assume 0, l'elemento di indice 1 assume 1, l'elemento di indice 2 assume 2
    l'elemento di indice 9 assume 9, l'elemento di indice 10 assume 0, l'elemento di indice 11 assume 1 e così via.
    Inoltre, per far si che il valore di labels non cambi nonostante la funzione sample_image venga chiamata più volte abbiamo wrappato
    tale Tensor all'interno di Variable"""
    """Prendiamo il Tensor 2-D z e il Tensor 1-D labels e mandiamoli in ingresso al generatore"""
    gen_imgs = generator(z, labels)
    """Il numero di immmagini che vengono prodotte in uscita dal gneratore è pari a n_row**2"""
    save_image(gen_imgs.data, "results_images/Epoca%d.png" % epoch, nrow=n_row, normalize=True)
    """Tramite save_image all'interno della directory results_images che abbiamo creato
    precedentemente inseriamo una griglia costituita dalle n_row**2 immagini prodotte in uscita
    dal generatore disposte su n_row righe"""

# %%
for epoch in range(opt.n_epochs):
  history_d_minibatch_accuracy = []
  history_d_minibatch_loss = []
  history_g_minibatch_loss = []
  for i, (imgs, labels) in enumerate(dataloader):

        batch_size = imgs.shape[0] #64

        # Adversarial ground truths
        valid = Variable(FloatTensor(batch_size, 1).fill_(1.0), requires_grad=False)
        """valid è un Tensor 2-D avente un numero di righe pari a batch_size(64)
        e un numero di colonne pari a 1. Tale Tensor contiene tutti 1 e ci 
        serve per calcolare l'adversarial loss per le immagini reali
        """
        fake = Variable(FloatTensor(batch_size, 1).fill_(0.0), requires_grad=False)
        """fake è un Tensor 2-D avente un numero di righe pari a batch_size(64)
        e un numero di colonne pari a 1. Tale Tensor contiene tutti 0 e ci 
        serve per calcolare l'adversarial loss per le immagini fake
        """

        # Configure input
        """Invocando il metodo type su un Tensor è possibile effettuare il
        casting di tale Tensor"""
        real_imgs = Variable(imgs.type(FloatTensor))
        """real_imgs è un minibatch contenente un numero di immagini reali pari
        a minibatch_size(64)"""
        labels = Variable(labels.type(LongTensor))
        """labels è un minibatch contenente i minibatch_size(64) target
        corrispondenti alle 64 immagini reali presenti nel minibatch real_imgs"""

        # -----------------
        #  Train Generator
        # -----------------
        """Resettiamo il gradiente"""
        optimizer_G.zero_grad()

        # Sample noise and labels as generator input
        """z è un minibatch contenente 64 rumori casuali, ognuno di 100 elementi"""
        z = Variable(FloatTensor(np.random.normal(0, 1, (batch_size, opt.latent_dim))))
        """gen_labels è un Tensor 1-D contenente 64 (batch_size) target, uno per
        ogni singolo rumore casuale presente nel minibatch z"""
        gen_labels = Variable(LongTensor(np.random.randint(0, opt.n_classes, batch_size)))

        # Generate a batch of images
        gen_imgs = generator(z, gen_labels)
        """gen_imgs è un minibatch contenente le 64 immagini (batch_size)
        generate dal generatore"""
        # Loss measures generator's ability to fool the discriminator
        """A questo punto prendiamo il minibatch contenente le 64 immagini
        generate dal generatore e le mandiamo in ingresso al discriminatore"""
        validity, pred_label = discriminator(gen_imgs)
        g_loss = 0.5 * (adversarial_loss(validity, valid) + auxiliary_loss(pred_label, gen_labels))
        """Calcoliamo il gradiente della g_loss"""
        g_loss.backward()
        """Ottimizziamo i parametri del generatore"""
        optimizer_G.step()

        # ---------------------
        #  Train Discriminator
        # ---------------------
        """Resettiamo il gradiente"""
        optimizer_D.zero_grad()

        # Loss for real images
        real_pred, real_aux = discriminator(real_imgs)
        d_real_loss = (adversarial_loss(real_pred, valid) + auxiliary_loss(real_aux, labels)) / 2

        # Loss for fake images
        fake_pred, fake_aux = discriminator(gen_imgs.detach())
        """gen_imgs contiene le 64 (batch_size) immagini generate dal generatore
        durante la fase di training del generatore"""

        """Utilizzando detach() nel momento in cui attuiamo la backpropagation
        per aggiornare i parametri del discriminatore quello che accade è che
        effettivamente vengono aggiornati solo ed esclusivamente i parametri del
        discriminatore e non anche quelli del generatore.
        Se non usassimo detach() nel momento in cui attuaiamo la backpropagation
        per aggiornare i parametri del discriminatore, oltre ai parametri del
        discriminatore, verrebbero aggiornati anche quelli del generatore e questo
        non va bene in quanto vogliamo aggiornare solo i parametri del
        discriminatore"""
        d_fake_loss = (adversarial_loss(fake_pred, fake) + auxiliary_loss(fake_aux, gen_labels)) / 2

        # Total discriminator loss
        d_loss = (d_real_loss + d_fake_loss) / 2
        """Calcoliamo il gradiente della loss del discriminatore"""
        d_loss.backward()
        """Ottimizziamo i parametri del discriminatore"""
        optimizer_D.step()


        #Calcoliamo l'accuratezza del discriminatore nel classificare correttamente la classe di appartenenza di ogni singola immagine (fake o reale) che riceve
        pred = np.concatenate([real_aux.data.cpu().numpy(), fake_aux.data.cpu().numpy()], axis=0)
        """pred ha dimensione 128x10 in quanto è dato dalla concatenazione per riga
        di real_aux (Tensor 2-D di dimensione 64x10 contenente per ogni immagine reale fornita al discriminatore
        le probabilità con cui l'immagine appartiene ad ognuna delle 10 classi) e di
        fake_aux (Tensor 2-D di dimensione 64x10 contenente per ogni immagine fake fornita al discriminatore
        le probabilità con cui l'immagine appartiene ad ognuna delle 10 classi)"""
        target = np.concatenate([labels.data.cpu().numpy(), gen_labels.data.cpu().numpy()], axis=0)
        """target ha dimensione 128 in quanto è dato dalla concatenazione per riga
        di labels (Tensor 1-D di dimensione 64 contenente per ogni immagine reale fornita al discriminatore il relativo target)
        e di gen_labels (Tensor 1-D di dimensione 64 contenente per ogni immagine fake fornita al discriminatore il relativo target)
        """
        d_minibatch_accuracy = np.mean(np.argmax(pred, axis=1) == target)
        history_d_minibatch_accuracy.append(d_minibatch_accuracy)
        history_d_minibatch_loss.append(d_loss.item())
        history_g_minibatch_loss.append(g_loss.item())

        if (epoch+1) % opt.sample_interval == 0:
            sample_image(n_row=10, epoch=(epoch+1))

  d_epoch_accuracy = np.mean(history_d_minibatch_accuracy)
  d_epoch_loss = np.mean(history_d_minibatch_loss)
  g_epoch_loss = np.mean(history_g_minibatch_loss)
  print(f"Epoch {epoch+1}: Discriminator_Loss={d_epoch_loss:.4f}, Discriminator_Accuracy={d_epoch_accuracy*100:.4f}, Generator_Loss={g_epoch_loss:.4f}")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch 1: Discriminator_Loss=1.2911, Discriminator_Accuracy=58.5846, Generator_Loss=1.3520
# Epoch 2: Discriminator_Loss=1.1134, Discriminator_Accuracy=90.0969, Generator_Loss=1.1636
# Epoch 3: Discriminator_Loss=1.0976, Discriminator_Accuracy=93.0079, Generator_Loss=1.1464
# Epoch 4: Discriminator_Loss=1.0957, Discriminator_Accuracy=94.1098, Generator_Loss=1.1347
# Epoch 5: Discriminator_Loss=1.0958, Discriminator_Accuracy=94.8827, Generator_Loss=1.1215
# Epoch 6: Discriminator_Loss=1.0953, Discriminator_Accuracy=95.4374, Generator_Loss=1.1134
# Epoch 7: Discriminator_Loss=1.0941, Discriminator_Accuracy=95.8222, Generator_Loss=1.1092
# Epoch 8: Discriminator_Loss=1.0942, Discriminator_Accuracy=96.1171, Generator_Loss=1.1040
# Epoch 9: Discriminator_Loss=1.0951, Discriminator_Accuracy=96.4377, Generator_Loss=1.1005
# Epoch 10: Discriminator_Loss=1.0932, Discriminator_Accuracy=96.6884, Generator_Loss=1.0956
# Epoch 11: Discriminator_Loss=1.0928, Discriminator_Accuracy=96.8417, Generator_Loss=1.0937
# Epoch 12: Discriminator_Loss=1.0931, Discriminator_Accuracy=97.0507, Generator_Loss=1.0924
# Epoch 13: Discriminator_Loss=1.0918, Discriminator_Accuracy=97.1882, Generator_Loss=1.0897
# Epoch 14: Discriminator_Loss=1.0912, Discriminator_Accuracy=97.3098, Generator_Loss=1.0899
# Epoch 15: Discriminator_Loss=1.0910, Discriminator_Accuracy=97.4355, Generator_Loss=1.0884
# Epoch 16: Discriminator_Loss=1.0899, Discriminator_Accuracy=97.5530, Generator_Loss=1.0898
# Epoch 17: Discriminator_Loss=1.0888, Discriminator_Accuracy=97.7012, Generator_Loss=1.0864
# Epoch 18: Discriminator_Loss=1.0885, Discriminator_Accuracy=97.7187, Generator_Loss=1.0875
# Epoch 19: Discriminator_Loss=1.0869, Discriminator_Accuracy=97.8162, Generator_Loss=1.0878
# Epoch 20: Discriminator_Loss=1.0871, Discriminator_Accuracy=97.8511, Generator_Loss=1.0904
# Epoch 21: Discriminator_Loss=1.0869, Discriminator_Accuracy=97.8861, Generator_Loss=1.0910
# Epoch 22: Discriminator_Loss=1.0851, Discriminator_Accuracy=97.9977, Generator_Loss=1.0901
# Epoch 23: Discriminator_Loss=1.0862, Discriminator_Accuracy=98.0119, Generator_Loss=1.0917
# Epoch 24: Discriminator_Loss=1.0858, Discriminator_Accuracy=98.0835, Generator_Loss=1.0904
# Epoch 25: Discriminator_Loss=1.0843, Discriminator_Accuracy=98.1010, Generator_Loss=1.0884
# Epoch 26: Discriminator_Loss=1.0858, Discriminator_Accuracy=98.1585, Generator_Loss=1.0900
# Epoch 27: Discriminator_Loss=1.0849, Discriminator_Accuracy=98.1835, Generator_Loss=1.0867
# Epoch 28: Discriminator_Loss=1.0853, Discriminator_Accuracy=98.2259, Generator_Loss=1.0869
# Epoch 29: Discriminator_Loss=1.0858, Discriminator_Accuracy=98.1901, Generator_Loss=1.0875
# Epoch 30: Discriminator_Loss=1.0865, Discriminator_Accuracy=98.1926, Generator_Loss=1.0863
# Epoch 31: Discriminator_Loss=1.0853, Discriminator_Accuracy=98.2493, Generator_Loss=1.0842
# Epoch 32: Discriminator_Loss=1.0849, Discriminator_Accuracy=98.3084, Generator_Loss=1.0844
# Epoch 33: Discriminator_Loss=1.0864, Discriminator_Accuracy=98.3034, Generator_Loss=1.0860
# Epoch 34: Discriminator_Loss=1.0856, Discriminator_Accuracy=98.3317, Generator_Loss=1.0842
# Epoch 35: Discriminator_Loss=1.0858, Discriminator_Accuracy=98.3401, Generator_Loss=1.0856
# Epoch 36: Discriminator_Loss=1.0852, Discriminator_Accuracy=98.4067, Generator_Loss=1.0855
# Epoch 37: Discriminator_Loss=1.0848, Discriminator_Accuracy=98.4133, Generator_Loss=1.0858
# Epoch 38: Discriminator_Loss=1.0857, Discriminator_Accuracy=98.4658, Generator_Loss=1.0856
# Epoch 39: Discriminator_Loss=1.0865, Discriminator_Accuracy=98.4675, Generator_Loss=1.0842
# Epoch 40: Discriminator_Loss=1.0858, Discriminator_Accuracy=98.4392, Generator_Loss=1.0844
# Epoch 41: Discriminator_Loss=1.0857, Discriminator_Accuracy=98.4716, Generator_Loss=1.0820
# Epoch 42: Discriminator_Loss=1.0854, Discriminator_Accuracy=98.5091, Generator_Loss=1.0837
# Epoch 43: Discriminator_Loss=1.0845, Discriminator_Accuracy=98.4908, Generator_Loss=1.0819
# Epoch 44: Discriminator_Loss=1.0855, Discriminator_Accuracy=98.5175, Generator_Loss=1.0834
# Epoch 45: Discriminator_Loss=1.0854, Discriminator_Accuracy=98.5125, Generator_Loss=1.0812
# Epoch 46: Discriminator_Loss=1.0859, Discriminator_Accuracy=98.5283, Generator_Loss=1.0830
# Epoch 47: Discriminator_Loss=1.0846, Discriminator_Accuracy=98.6032, Generator_Loss=1.0818
# Epoch 48: Discriminator_Loss=1.0861, Discriminator_Accuracy=98.5374, Generator_Loss=1.0810
# Epoch 49: Discriminator_Loss=1.0843, Discriminator_Accuracy=98.5799, Generator_Loss=1.0798
# Epoch 50: Discriminator_Loss=1.0854, Discriminator_Accuracy=98.6382, Generator_Loss=1.0823
# Epoch 51: Discriminator_Loss=1.0848, Discriminator_Accuracy=98.6299, Generator_Loss=1.0815
# Epoch 52: Discriminator_Loss=1.0856, Discriminator_Accuracy=98.6141, Generator_Loss=1.0814
# Epoch 53: Discriminator_Loss=1.0847, Discriminator_Accuracy=98.6865, Generator_Loss=1.0801
# Epoch 54: Discriminator_Loss=1.0844, Discriminator_Accuracy=98.6674, Generator_Loss=1.0821
# Epoch 55: Discriminator_Loss=1.0853, Discriminator_Accuracy=98.6574, Generator_Loss=1.0818
# Epoch 56: Discriminator_Loss=1.0844, Discriminator_Accuracy=98.6624, Generator_Loss=1.0800
# Epoch 57: Discriminator_Loss=1.0853, Discriminator_Accuracy=98.6541, Generator_Loss=1.0815
# Epoch 58: Discriminator_Loss=1.0850, Discriminator_Accuracy=98.6915, Generator_Loss=1.0801
# Epoch 59: Discriminator_Loss=1.0851, Discriminator_Accuracy=98.7290, Generator_Loss=1.0809
# Epoch 60: Discriminator_Loss=1.0850, Discriminator_Accuracy=98.6982, Generator_Loss=1.0806
# Epoch 61: Discriminator_Loss=1.0850, Discriminator_Accuracy=98.7074, Generator_Loss=1.0792
# Epoch 62: Discriminator_Loss=1.0845, Discriminator_Accuracy=98.7040, Generator_Loss=1.0806
# Epoch 63: Discriminator_Loss=1.0844, Discriminator_Accuracy=98.7582, Generator_Loss=1.0791
# Epoch 64: Discriminator_Loss=1.0847, Discriminator_Accuracy=98.7632, Generator_Loss=1.0808
# Epoch 65: Discriminator_Loss=1.0847, Discriminator_Accuracy=98.7773, Generator_Loss=1.0798
# Epoch 66: Discriminator_Loss=1.0850, Discriminator_Accuracy=98.7540, Generator_Loss=1.0800
# Epoch 67: Discriminator_Loss=1.0843, Discriminator_Accuracy=98.7715, Generator_Loss=1.0803
# Epoch 68: Discriminator_Loss=1.0840, Discriminator_Accuracy=98.8298, Generator_Loss=1.0795
# Epoch 69: Discriminator_Loss=1.0847, Discriminator_Accuracy=98.7807, Generator_Loss=1.0797
# Epoch 70: Discriminator_Loss=1.0842, Discriminator_Accuracy=98.7848, Generator_Loss=1.0787
# Epoch 71: Discriminator_Loss=1.0851, Discriminator_Accuracy=98.8040, Generator_Loss=1.0782
# Epoch 72: Discriminator_Loss=1.0842, Discriminator_Accuracy=98.8173, Generator_Loss=1.0785
# Epoch 73: Discriminator_Loss=1.0846, Discriminator_Accuracy=98.8306, Generator_Loss=1.0791
# Epoch 74: Discriminator_Loss=1.0845, Discriminator_Accuracy=98.8464, Generator_Loss=1.0789
# Epoch 75: Discriminator_Loss=1.0842, Discriminator_Accuracy=98.8331, Generator_Loss=1.0775
# Epoch 76: Discriminator_Loss=1.0845, Discriminator_Accuracy=98.8073, Generator_Loss=1.0786
# Epoch 77: Discriminator_Loss=1.0848, Discriminator_Accuracy=98.8273, Generator_Loss=1.0792
# Epoch 78: Discriminator_Loss=1.0843, Discriminator_Accuracy=98.8290, Generator_Loss=1.0786
# Epoch 79: Discriminator_Loss=1.0839, Discriminator_Accuracy=98.8823, Generator_Loss=1.0784
# Epoch 80: Discriminator_Loss=1.0845, Discriminator_Accuracy=98.8523, Generator_Loss=1.0779
# Epoch 81: Discriminator_Loss=1.0837, Discriminator_Accuracy=98.8956, Generator_Loss=1.0792
# Epoch 82: Discriminator_Loss=1.0839, Discriminator_Accuracy=98.8698, Generator_Loss=1.0783
# Epoch 83: Discriminator_Loss=1.0841, Discriminator_Accuracy=98.9056, Generator_Loss=1.0779
# Epoch 84: Discriminator_Loss=1.0840, Discriminator_Accuracy=98.8673, Generator_Loss=1.0780
# Epoch 85: Discriminator_Loss=1.0841, Discriminator_Accuracy=98.9081, Generator_Loss=1.0783
# Epoch 86: Discriminator_Loss=1.0839, Discriminator_Accuracy=98.9247, Generator_Loss=1.0780
# Epoch 87: Discriminator_Loss=1.0842, Discriminator_Accuracy=98.9372, Generator_Loss=1.0783
# Epoch 88: Discriminator_Loss=1.0837, Discriminator_Accuracy=98.9189, Generator_Loss=1.0784
# Epoch 89: Discriminator_Loss=1.0836, Discriminator_Accuracy=98.9347, Generator_Loss=1.0786
# Epoch 90: Discriminator_Loss=1.0837, Discriminator_Accuracy=98.9481, Generator_Loss=1.0783
# Epoch 91: Discriminator_Loss=1.0830, Discriminator_Accuracy=98.9664, Generator_Loss=1.0780
# Epoch 92: Discriminator_Loss=1.0837, Discriminator_Accuracy=98.9739, Generator_Loss=1.0786
# Epoch 93: Discriminator_Loss=1.0832, Discriminator_Accuracy=98.9780, Generator_Loss=1.0777
# Epoch 94: Discriminator_Loss=1.0833, Discriminator_Accuracy=98.9389, Generator_Loss=1.0774
# Epoch 95: Discriminator_Loss=1.0833, Discriminator_Accuracy=98.9914, Generator_Loss=1.0791
# Epoch 96: Discriminator_Loss=1.0837, Discriminator_Accuracy=98.9930, Generator_Loss=1.0782
# Epoch 97: Discriminator_Loss=1.0836, Discriminator_Accuracy=98.9656, Generator_Loss=1.0782
# Epoch 98: Discriminator_Loss=1.0833, Discriminator_Accuracy=99.0205, Generator_Loss=1.0784
# Epoch 99: Discriminator_Loss=1.0833, Discriminator_Accuracy=98.9797, Generator_Loss=1.0786
# Epoch 100: Discriminator_Loss=1.0835, Discriminator_Accuracy=99.0214, Generator_Loss=1.0784
# Epoch 101: Discriminator_Loss=1.0832, Discriminator_Accuracy=98.9805, Generator_Loss=1.0785
# Epoch 102: Discriminator_Loss=1.0834, Discriminator_Accuracy=99.0005, Generator_Loss=1.0784
# Epoch 103: Discriminator_Loss=1.0834, Discriminator_Accuracy=99.0372, Generator_Loss=1.0785
# Epoch 104: Discriminator_Loss=1.0829, Discriminator_Accuracy=99.0089, Generator_Loss=1.0783
# Epoch 105: Discriminator_Loss=1.0833, Discriminator_Accuracy=99.0114, Generator_Loss=1.0787
# Epoch 106: Discriminator_Loss=1.0832, Discriminator_Accuracy=99.0447, Generator_Loss=1.0779
# Epoch 107: Discriminator_Loss=1.0834, Discriminator_Accuracy=99.0488, Generator_Loss=1.0779
# Epoch 108: Discriminator_Loss=1.0834, Discriminator_Accuracy=99.0255, Generator_Loss=1.0780
# Epoch 109: Discriminator_Loss=1.0831, Discriminator_Accuracy=99.0180, Generator_Loss=1.0781
# Epoch 110: Discriminator_Loss=1.0831, Discriminator_Accuracy=99.0172, Generator_Loss=1.0777
# Epoch 111: Discriminator_Loss=1.0827, Discriminator_Accuracy=99.0338, Generator_Loss=1.0772
# Epoch 112: Discriminator_Loss=1.0832, Discriminator_Accuracy=99.0330, Generator_Loss=1.0786
# Epoch 113: Discriminator_Loss=1.0834, Discriminator_Accuracy=99.0505, Generator_Loss=1.0773
# Epoch 114: Discriminator_Loss=1.0832, Discriminator_Accuracy=99.0305, Generator_Loss=1.0782
# Epoch 115: Discriminator_Loss=1.0831, Discriminator_Accuracy=99.0397, Generator_Loss=1.0781
# Epoch 116: Discriminator_Loss=1.0834, Discriminator_Accuracy=99.0722, Generator_Loss=1.0780
# Epoch 117: Discriminator_Loss=1.0831, Discriminator_Accuracy=99.0488, Generator_Loss=1.0776
# Epoch 118: Discriminator_Loss=1.0833, Discriminator_Accuracy=99.0780, Generator_Loss=1.0785
# Epoch 119: Discriminator_Loss=1.0833, Discriminator_Accuracy=99.0738, Generator_Loss=1.0779
# Epoch 120: Discriminator_Loss=1.0828, Discriminator_Accuracy=99.0855, Generator_Loss=1.0779
# Epoch 121: Discriminator_Loss=1.0830, Discriminator_Accuracy=99.0563, Generator_Loss=1.0774
# Epoch 122: Discriminator_Loss=1.0830, Discriminator_Accuracy=99.1088, Generator_Loss=1.0780
# Epoch 123: Discriminator_Loss=1.0830, Discriminator_Accuracy=99.0930, Generator_Loss=1.0776
# Epoch 124: Discriminator_Loss=1.0829, Discriminator_Accuracy=99.1180, Generator_Loss=1.0779
# Epoch 125: Discriminator_Loss=1.0826, Discriminator_Accuracy=99.1005, Generator_Loss=1.0779
# Epoch 126: Discriminator_Loss=1.0835, Discriminator_Accuracy=99.0672, Generator_Loss=1.0774
# Epoch 127: Discriminator_Loss=1.0831, Discriminator_Accuracy=99.0905, Generator_Loss=1.0772
# Epoch 128: Discriminator_Loss=1.0833, Discriminator_Accuracy=99.0813, Generator_Loss=1.0774
# Epoch 129: Discriminator_Loss=1.0831, Discriminator_Accuracy=99.0971, Generator_Loss=1.0777
# Epoch 130: Discriminator_Loss=1.0828, Discriminator_Accuracy=99.1171, Generator_Loss=1.0777
# Epoch 131: Discriminator_Loss=1.0830, Discriminator_Accuracy=99.0847, Generator_Loss=1.0778
# Epoch 132: Discriminator_Loss=1.0830, Discriminator_Accuracy=99.1180, Generator_Loss=1.0776
# Epoch 133: Discriminator_Loss=1.0827, Discriminator_Accuracy=99.1263, Generator_Loss=1.0777
# Epoch 134: Discriminator_Loss=1.0828, Discriminator_Accuracy=99.0971, Generator_Loss=1.0771
# Epoch 135: Discriminator_Loss=1.0828, Discriminator_Accuracy=99.1230, Generator_Loss=1.0771
# Epoch 136: Discriminator_Loss=1.0830, Discriminator_Accuracy=99.0772, Generator_Loss=1.0773
# Epoch 137: Discriminator_Loss=1.0827, Discriminator_Accuracy=99.1530, Generator_Loss=1.0774
# Epoch 138: Discriminator_Loss=1.0827, Discriminator_Accuracy=99.1371, Generator_Loss=1.0770
# Epoch 139: Discriminator_Loss=1.0825, Discriminator_Accuracy=99.1696, Generator_Loss=1.0776
# Epoch 140: Discriminator_Loss=1.0827, Discriminator_Accuracy=99.1588, Generator_Loss=1.0774
# Epoch 141: Discriminator_Loss=1.0826, Discriminator_Accuracy=99.1704, Generator_Loss=1.0771
# Epoch 142: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.1621, Generator_Loss=1.0778
# Epoch 143: Discriminator_Loss=1.0826, Discriminator_Accuracy=99.1771, Generator_Loss=1.0777
# Epoch 144: Discriminator_Loss=1.0829, Discriminator_Accuracy=99.1505, Generator_Loss=1.0777
# Epoch 145: Discriminator_Loss=1.0825, Discriminator_Accuracy=99.1738, Generator_Loss=1.0778
# Epoch 146: Discriminator_Loss=1.0828, Discriminator_Accuracy=99.1438, Generator_Loss=1.0777
# Epoch 147: Discriminator_Loss=1.0826, Discriminator_Accuracy=99.1654, Generator_Loss=1.0773
# Epoch 148: Discriminator_Loss=1.0824, Discriminator_Accuracy=99.1488, Generator_Loss=1.0775
# Epoch 149: Discriminator_Loss=1.0826, Discriminator_Accuracy=99.1579, Generator_Loss=1.0772
# Epoch 150: Discriminator_Loss=1.0825, Discriminator_Accuracy=99.1654, Generator_Loss=1.0773
# Epoch 151: Discriminator_Loss=1.0826, Discriminator_Accuracy=99.1996, Generator_Loss=1.0778
# Epoch 152: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.2071, Generator_Loss=1.0778
# Epoch 153: Discriminator_Loss=1.0824, Discriminator_Accuracy=99.1846, Generator_Loss=1.0777
# Epoch 154: Discriminator_Loss=1.0824, Discriminator_Accuracy=99.1688, Generator_Loss=1.0773
# Epoch 155: Discriminator_Loss=1.0826, Discriminator_Accuracy=99.1988, Generator_Loss=1.0774
# Epoch 156: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.2154, Generator_Loss=1.0774
# Epoch 157: Discriminator_Loss=1.0825, Discriminator_Accuracy=99.2129, Generator_Loss=1.0777
# Epoch 158: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.1963, Generator_Loss=1.0776
# Epoch 159: Discriminator_Loss=1.0825, Discriminator_Accuracy=99.2029, Generator_Loss=1.0772
# Epoch 160: Discriminator_Loss=1.0825, Discriminator_Accuracy=99.1996, Generator_Loss=1.0775
# Epoch 161: Discriminator_Loss=1.0824, Discriminator_Accuracy=99.2504, Generator_Loss=1.0773
# Epoch 162: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.2113, Generator_Loss=1.0773
# Epoch 163: Discriminator_Loss=1.0822, Discriminator_Accuracy=99.2146, Generator_Loss=1.0768
# Epoch 164: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.2104, Generator_Loss=1.0773
# Epoch 165: Discriminator_Loss=1.0821, Discriminator_Accuracy=99.2579, Generator_Loss=1.0771
# Epoch 166: Discriminator_Loss=1.0824, Discriminator_Accuracy=99.2204, Generator_Loss=1.0773
# Epoch 167: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.2254, Generator_Loss=1.0776
# Epoch 168: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.2304, Generator_Loss=1.0774
# Epoch 169: Discriminator_Loss=1.0825, Discriminator_Accuracy=99.1996, Generator_Loss=1.0770
# Epoch 170: Discriminator_Loss=1.0820, Discriminator_Accuracy=99.2404, Generator_Loss=1.0774
# Epoch 171: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.2437, Generator_Loss=1.0770
# Epoch 172: Discriminator_Loss=1.0822, Discriminator_Accuracy=99.2387, Generator_Loss=1.0771
# Epoch 173: Discriminator_Loss=1.0821, Discriminator_Accuracy=99.2554, Generator_Loss=1.0771
# Epoch 174: Discriminator_Loss=1.0821, Discriminator_Accuracy=99.2462, Generator_Loss=1.0773
# Epoch 175: Discriminator_Loss=1.0824, Discriminator_Accuracy=99.2296, Generator_Loss=1.0775
# Epoch 176: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.2337, Generator_Loss=1.0771
# Epoch 177: Discriminator_Loss=1.0823, Discriminator_Accuracy=99.2446, Generator_Loss=1.0776
# Epoch 178: Discriminator_Loss=1.0822, Discriminator_Accuracy=99.2237, Generator_Loss=1.0774
# Epoch 179: Discriminator_Loss=1.0819, Discriminator_Accuracy=99.2870, Generator_Loss=1.0768
# Epoch 180: Discriminator_Loss=1.0822, Discriminator_Accuracy=99.2671, Generator_Loss=1.0777
# Epoch 181: Discriminator_Loss=1.0819, Discriminator_Accuracy=99.2812, Generator_Loss=1.0774
# Epoch 182: Discriminator_Loss=1.0818, Discriminator_Accuracy=99.2904, Generator_Loss=1.0767
# Epoch 183: Discriminator_Loss=1.0820, Discriminator_Accuracy=99.2462, Generator_Loss=1.0774
# Epoch 184: Discriminator_Loss=1.0820, Discriminator_Accuracy=99.2904, Generator_Loss=1.0773
# Epoch 185: Discriminator_Loss=1.0821, Discriminator_Accuracy=99.2704, Generator_Loss=1.0772
# Epoch 186: Discriminator_Loss=1.0821, Discriminator_Accuracy=99.2696, Generator_Loss=1.0772
# Epoch 187: Discriminator_Loss=1.0819, Discriminator_Accuracy=99.2721, Generator_Loss=1.0771
# Epoch 188: Discriminator_Loss=1.0821, Discriminator_Accuracy=99.2579, Generator_Loss=1.0771
# Epoch 189: Discriminator_Loss=1.0820, Discriminator_Accuracy=99.2962, Generator_Loss=1.0771
# Epoch 190: Discriminator_Loss=1.0818, Discriminator_Accuracy=99.2904, Generator_Loss=1.0776
# Epoch 191: Discriminator_Loss=1.0821, Discriminator_Accuracy=99.3045, Generator_Loss=1.0772
# Epoch 192: Discriminator_Loss=1.0821, Discriminator_Accuracy=99.2762, Generator_Loss=1.0770
# Epoch 193: Discriminator_Loss=1.0820, Discriminator_Accuracy=99.2845, Generator_Loss=1.0777
# Epoch 194: Discriminator_Loss=1.0821, Discriminator_Accuracy=99.2704, Generator_Loss=1.0774
# Epoch 195: Discriminator_Loss=1.0819, Discriminator_Accuracy=99.2779, Generator_Loss=1.0768
# Epoch 196: Discriminator_Loss=1.0817, Discriminator_Accuracy=99.3129, Generator_Loss=1.0767
# Epoch 197: Discriminator_Loss=1.0818, Discriminator_Accuracy=99.3054, Generator_Loss=1.0774
# Epoch 198: Discriminator_Loss=1.0820, Discriminator_Accuracy=99.2820, Generator_Loss=1.0776
# Epoch 199: Discriminator_Loss=1.0817, Discriminator_Accuracy=99.3237, Generator_Loss=1.0774
# Epoch 200: Discriminator_Loss=1.0820, Discriminator_Accuracy=99.2796, Generator_Loss=1.0773
